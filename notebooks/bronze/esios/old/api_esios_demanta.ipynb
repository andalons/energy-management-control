# %%
import requests
import json
from datetime import datetime

# %%
# 📌 Headers con autenticación
headers = {
    "Accept": "application/json; application/vnd.esios-api-v1+json",
    "Content-Type": "application/json",
    "x-api-key": "273695bb4f30b8ab8de054a0410ee2a9d09c97a5006e3a07c27615e6c60888a7"
}

# %%
url= "https://api.esios.ree.es/indicators/1293"
url= url+"?start_date=2024-01-01T00:00&end_date=2024-01-01T23:55"

# %%
# Realizar la solicitud GET
response = requests.get(url, headers=headers)

# %%
response.raise_for_status() #response.content

# %%
data= response.json()

# %%
# Guardar JSON en archivo solicitado
filename = "demanda_Resto.json"
with open(filename, "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

# Imprimir confirmación mínima
print(f"Guardado {filename} ({len(json.dumps(data))} bytes) - {datetime.utcnow().isoformat()}Z")
# Out:
# Guardado demanda_Resto.json (55089 bytes) - 2025-10-09T11:20:41.149519Z

# %%
data_json =data['indicator']

# %%
# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    data = response. json() # Convertir la respuesta en formato JSON
    print("Datos recibidos:", data) # Mostrar los datos recibidos
else:
    print(f"Error: {response.status_code}") # Mostrar el código de e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Verificar si la solicitud fue exitosa
# ----> 2 if response.status_code == 200:
#       3     data = response. json() # Convertir la respuesta en formato JSON
#       4     print("Datos recibidos:", data) # Mostrar los datos recibidos
#
# NameError: name 'response' is not defined

# %%
data['indicator']
# Out:
# {'name': 'Término de facturación de energía activa del PVPC 2.0TD P2 llano ',
#  'short_name': 'PVPC T. 2.0TD P2',
#  'id': 1004,
#  'composited': False,
#  'step_type': 'linear',
#  'disaggregated': True,
#  'magnitud': [{'name': 'Precio €/MWh', 'id': 23}],
#  'tiempo': [{'name': 'Hora', 'id': 4}],
#  'geos': [{'geo_id': 8741, 'geo_name': 'Península'},
#   {'geo_id': 8742, 'geo_name': 'Canarias'},
#   {'geo_id': 8743, 'geo_name': 'Baleares'},
#   {'geo_id': 8744, 'geo_name': 'Ceuta'},
#   {'geo_id': 8745, 'geo_name': 'Melilla'}],
#  'values_updated_at': '2025-09-22T20:46:08.000+02:00',
#  'values': [{'value': 163.13,
#    'datetime': '2025-09-23T08:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T06:00:00Z',
#    'tz_time': '2025-09-23T06:00:00.000Z',
#    'geo_id': 8741,
#    'geo_name': 'Península'},
#   {'value': 163.13,
#    'datetime': '2025-09-23T08:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T06:00:00Z',
#    'tz_time': '2025-09-23T06:00:00.000Z',
#    'geo_id': 8742,
#    'geo_name': 'Canarias'},
#   {'value': 163.13,
#    'datetime': '2025-09-23T08:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T06:00:00Z',
#    'tz_time': '2025-09-23T06:00:00.000Z',
#    'geo_id': 8743,
#    'geo_name': 'Baleares'},
#   {'value': 163.13,
#    'datetime': '2025-09-23T08:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T06:00:00Z',
#    'tz_time': '2025-09-23T06:00:00.000Z',
#    'geo_id': 8744,
#    'geo_name': 'Ceuta'},
#   {'value': 163.13,
#    'datetime': '2025-09-23T08:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T06:00:00Z',
#    'tz_time': '2025-09-23T06:00:00.000Z',
#    'geo_id': 8745,
#    'geo_name': 'Melilla'},
#   {'value': 114.56,
#    'datetime': '2025-09-23T09:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T07:00:00Z',
#    'tz_time': '2025-09-23T07:00:00.000Z',
#    'geo_id': 8741,
#    'geo_name': 'Península'},
#   {'value': 114.56,
#    'datetime': '2025-09-23T09:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T07:00:00Z',
#    'tz_time': '2025-09-23T07:00:00.000Z',
#    'geo_id': 8742,
#    'geo_name': 'Canarias'},
#   {'value': 114.56,
#    'datetime': '2025-09-23T09:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T07:00:00Z',
#    'tz_time': '2025-09-23T07:00:00.000Z',
#    'geo_id': 8743,
#    'geo_name': 'Baleares'},
#   {'value': 114.56,
#    'datetime': '2025-09-23T09:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T07:00:00Z',
#    'tz_time': '2025-09-23T07:00:00.000Z',
#    'geo_id': 8744,
#    'geo_name': 'Ceuta'},
#   {'value': 114.56,
#    'datetime': '2025-09-23T09:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T07:00:00Z',
#    'tz_time': '2025-09-23T07:00:00.000Z',
#    'geo_id': 8745,
#    'geo_name': 'Melilla'},
#   {'value': 75.45,
#    'datetime': '2025-09-23T10:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T08:00:00Z',
#    'tz_time': '2025-09-23T08:00:00.000Z',
#    'geo_id': 8744,
#    'geo_name': 'Ceuta'},
#   {'value': 75.45,
#    'datetime': '2025-09-23T10:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T08:00:00Z',
#    'tz_time': '2025-09-23T08:00:00.000Z',
#    'geo_id': 8745,
#    'geo_name': 'Melilla'},
#   {'value': 67.46,
#    'datetime': '2025-09-23T14:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T12:00:00Z',
#    'tz_time': '2025-09-23T12:00:00.000Z',
#    'geo_id': 8741,
#    'geo_name': 'Península'},
#   {'value': 67.46,
#    'datetime': '2025-09-23T14:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T12:00:00Z',
#    'tz_time': '2025-09-23T12:00:00.000Z',
#    'geo_id': 8742,
#    'geo_name': 'Canarias'},
#   {'value': 67.46,
#    'datetime': '2025-09-23T14:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T12:00:00Z',
#    'tz_time': '2025-09-23T12:00:00.000Z',
#    'geo_id': 8743,
#    'geo_name': 'Baleares'},
#   {'value': 67.83,
#    'datetime': '2025-09-23T15:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T13:00:00Z',
#    'tz_time': '2025-09-23T13:00:00.000Z',
#    'geo_id': 8741,
#    'geo_name': 'Península'},
#   {'value': 67.83,
#    'datetime': '2025-09-23T15:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T13:00:00Z',
#    'tz_time': '2025-09-23T13:00:00.000Z',
#    'geo_id': 8742,
#    'geo_name': 'Canarias'},
#   {'value': 67.83,
#    'datetime': '2025-09-23T15:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T13:00:00Z',
#    'tz_time': '2025-09-23T13:00:00.000Z',
#    'geo_id': 8743,
#    'geo_name': 'Baleares'},
#   {'value': 67.83,
#    'datetime': '2025-09-23T15:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T13:00:00Z',
#    'tz_time': '2025-09-23T13:00:00.000Z',
#    'geo_id': 8744,
#    'geo_name': 'Ceuta'},
#   {'value': 67.83,
#    'datetime': '2025-09-23T15:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T13:00:00Z',
#    'tz_time': '2025-09-23T13:00:00.000Z',
#    'geo_id': 8745,
#    'geo_name': 'Melilla'},
#   {'value': 67.93,
#    'datetime': '2025-09-23T16:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T14:00:00Z',
#    'tz_time': '2025-09-23T14:00:00.000Z',
#    'geo_id': 8741,
#    'geo_name': 'Península'},
#   {'value': 67.93,
#    'datetime': '2025-09-23T16:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T14:00:00Z',
#    'tz_time': '2025-09-23T14:00:00.000Z',
#    'geo_id': 8742,
#    'geo_name': 'Canarias'},
#   {'value': 67.93,
#    'datetime': '2025-09-23T16:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T14:00:00Z',
#    'tz_time': '2025-09-23T14:00:00.000Z',
#    'geo_id': 8743,
#    'geo_name': 'Baleares'},
#   {'value': 67.93,
#    'datetime': '2025-09-23T16:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T14:00:00Z',
#    'tz_time': '2025-09-23T14:00:00.000Z',
#    'geo_id': 8744,
#    'geo_name': 'Ceuta'},
#   {'value': 67.93,
#    'datetime': '2025-09-23T16:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T14:00:00Z',
#    'tz_time': '2025-09-23T14:00:00.000Z',
#    'geo_id': 8745,
#    'geo_name': 'Melilla'},
#   {'value': 70.7,
#    'datetime': '2025-09-23T17:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T15:00:00Z',
#    'tz_time': '2025-09-23T15:00:00.000Z',
#    'geo_id': 8741,
#    'geo_name': 'Península'},
#   {'value': 70.7,
#    'datetime': '2025-09-23T17:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T15:00:00Z',
#    'tz_time': '2025-09-23T15:00:00.000Z',
#    'geo_id': 8742,
#    'geo_name': 'Canarias'},
#   {'value': 70.7,
#    'datetime': '2025-09-23T17:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T15:00:00Z',
#    'tz_time': '2025-09-23T15:00:00.000Z',
#    'geo_id': 8743,
#    'geo_name': 'Baleares'},
#   {'value': 70.7,
#    'datetime': '2025-09-23T17:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T15:00:00Z',
#    'tz_time': '2025-09-23T15:00:00.000Z',
#    'geo_id': 8744,
#    'geo_name': 'Ceuta'},
#   {'value': 70.7,
#    'datetime': '2025-09-23T17:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T15:00:00Z',
#    'tz_time': '2025-09-23T15:00:00.000Z',
#    'geo_id': 8745,
#    'geo_name': 'Melilla'},
#   {'value': 99.73,
#    'datetime': '2025-09-23T18:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T16:00:00Z',
#    'tz_time': '2025-09-23T16:00:00.000Z',
#    'geo_id': 8744,
#    'geo_name': 'Ceuta'},
#   {'value': 99.73,
#    'datetime': '2025-09-23T18:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T16:00:00Z',
#    'tz_time': '2025-09-23T16:00:00.000Z',
#    'geo_id': 8745,
#    'geo_name': 'Melilla'},
#   {'value': 156.63,
#    'datetime': '2025-09-23T22:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T20:00:00Z',
#    'tz_time': '2025-09-23T20:00:00.000Z',
#    'geo_id': 8741,
#    'geo_name': 'Península'},
#   {'value': 156.63,
#    'datetime': '2025-09-23T22:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T20:00:00Z',
#    'tz_time': '2025-09-23T20:00:00.000Z',
#    'geo_id': 8742,
#    'geo_name': 'Canarias'},
#   {'value': 156.63,
#    'datetime': '2025-09-23T22:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T20:00:00Z',
#    'tz_time': '2025-09-23T20:00:00.000Z',
#    'geo_id': 8743,
#    'geo_name': 'Baleares'},
#   {'value': 158.55,
#    'datetime': '2025-09-23T23:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T21:00:00Z',
#    'tz_time': '2025-09-23T21:00:00.000Z',
#    'geo_id': 8741,
#    'geo_name': 'Península'},
#   {'value': 158.55,
#    'datetime': '2025-09-23T23:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T21:00:00Z',
#    'tz_time': '2025-09-23T21:00:00.000Z',
#    'geo_id': 8742,
#    'geo_name': 'Canarias'},
#   {'value': 158.55,
#    'datetime': '2025-09-23T23:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T21:00:00Z',
#    'tz_time': '2025-09-23T21:00:00.000Z',
#    'geo_id': 8743,
#    'geo_name': 'Baleares'},
#   {'value': 158.55,
#    'datetime': '2025-09-23T23:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T21:00:00Z',
#    'tz_time': '2025-09-23T21:00:00.000Z',
#    'geo_id': 8744,
#    'geo_name': 'Ceuta'},
#   {'value': 158.55,
#    'datetime': '2025-09-23T23:00:00.000+02:00',
#    'datetime_utc': '2025-09-23T21:00:00Z',
#    'tz_time': '2025-09-23T21:00:00.000Z',
#    'geo_id': 8745,
#    'geo_name': 'Melilla'}]}

# %%
pip install python-esios
# Out:
# Requirement already satisfied: python-esios in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (0.2.7)
# Requirement already satisfied: requests in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from python-esios) (2.32.5)
# Requirement already satisfied: pandas in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from python-esios) (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from pandas->python-esios) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from pandas->python-esios) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from pandas->python-esios) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from pandas->python-esios) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->python-esios) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from requests->python-esios) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from requests->python-esios) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from requests->python-esios) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\my documents\cursos\bootcamp ia\energy-management-control\.venv\lib\site-packages (from requests->python-esios) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from esios import ESIOSClient

client = ESIOSClient(api_key_esios='273695bb4f30b8ab8de054a0410ee2a9d09c97a5006e3a07c27615e6c60888a7')
endpoint = client.endpoint (name='indicators')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from esios import ESIOSClient
#       3 client = ESIOSClient(api_key_esios='273695bb4f30b8ab8de054a0410ee2a9d09c97a5006e3a07c27615e6c60888a7')
#       4 endpoint = client.endpoint (name='indicators')
#
# ImportError: cannot import name 'ESIOSClient' from 'esios' (unknown location)

# %%
df_indicator = endpoint.list()
df_indicator
# Out:
#                                                    name  \
# 0              Generación programada PBF Hidráulica UGH
# 1           Generación programada PBF Hidráulica no UGH
# 2          Generación programada PBF Turbinación bombeo
# 3                     Generación programada PBF Nuclear
# 4     Generación programada PBF Hulla antracita Anex...
# ...                                                 ...
# 1962  Porcentaje de Energía Renovable No Integrable ...
# 1963  Precio medio ponderado reserva de regulación s...
# 1964                  Almacenamiento total programa p48
# 1965  Necesidad total solicitada de energías de bala...
# 1966      Porcentaje de Generación Renovable Peninsular
#
#                                             description  \
# 0     Es el programa de energía diario, con desglose...
# 1     Es el programa de energía diario, con desglose...
# 2     Es el programa de energía diario, con desglose...
# 3     Es el programa de energía diario, con desglose...
# 4     Es el programa de energía diario, con desglose...
# ...                                                 ...
# 1962  El proceso de solución de restricciones técnic...
# 1963  La regulación secundaria es un servicio comple...
# 1964
# 1965  La regulación terciaria se corresponde con el ...
# 1966
#
#                                       short_name     id
# 0                                 Hidráulica UGH      1
# 1                              Hidráulica no UGH      2
# 2                             Turbinación bombeo      3
# 3                                        Nuclear      4
# 4                    Hulla antracita RD 134/2010      5
# ...                                          ...    ...
# 1962                                % ERNI TOTAL  10462
# 1963      Banda de regulación secundaria a bajar  10463
# 1964                        Total Almacenamiento  10464
# 1965  Necesidad total solicitada mFRR programada  10485
# 1966                        Generación Renovable  10491
#
# [1967 rows x 4 columns]

# %%
indicador = endpoint.select(id=84)

# %%
df_price = indicador.historical(start='2023-01-01', end='2023-01-31')
df_price
# Out:
#                               84  geo_id   geo_name
# datetime
# 2023-01-01 00:00:00+01:00  0.050    8741  Península
# 2023-01-01 00:15:00+01:00  0.050    8741  Península
# 2023-01-01 00:30:00+01:00  0.050    8741  Península
# 2023-01-01 00:45:00+01:00  0.050    8741  Península
# 2023-01-01 01:00:00+01:00  0.050    8741  Península
# ...                          ...     ...        ...
# 2023-01-31 22:45:00+01:00  3.675    8741  Península
# 2023-01-31 23:00:00+01:00  2.350    8741  Península
# 2023-01-31 23:15:00+01:00  2.350    8741  Península
# 2023-01-31 23:30:00+01:00  2.350    8741  Península
# 2023-01-31 23:45:00+01:00  2.350    8741  Península
#
# [2976 rows x 3 columns]

# %%
df_price.columns
# Out:
# Index(['84', 'geo_id', 'geo_name'], dtype='object')
