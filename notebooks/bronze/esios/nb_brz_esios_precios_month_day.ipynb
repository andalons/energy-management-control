# %%
import os, re, unicodedata
from datetime import datetime
from pyspark.sql import SparkSession, functions as F
from notebookutils import mssparkutils
# Out:
# StatementMeta(, 692ff7bd-a54e-4a36-9454-80d9d7e7a9ea, 3, Finished, Available, Finished)

# %%
# ---------- Spark ----------
spark = SparkSession.builder.getOrCreate()
# Out:
# StatementMeta(, 692ff7bd-a54e-4a36-9454-80d9d7e7a9ea, 4, Finished, Available, Finished)

# %%
# Seleccionar el Lakehouse destino (bronze)
spark.sql("USE lh_bronze")
# Out:
# StatementMeta(, 692ff7bd-a54e-4a36-9454-80d9d7e7a9ea, 5, Finished, Available, Finished)
# DataFrame[]

# %%
# 📂 Carpetas bronze (donde ya están los JSON)
bronze_base_logical = "Files/bronze/ESIOS/data/mercados/componentes-precio"
bronze_base_physical = "/lakehouse/default/Files/bronze/ESIOS/data/mercados/componentes-precio"
# Out:
# StatementMeta(, 692ff7bd-a54e-4a36-9454-80d9d7e7a9ea, 6, Finished, Available, Finished)

# %%
# 📂 Salida (Tables/)
tables_prefix = "Tables"
# Out:
# StatementMeta(, 692ff7bd-a54e-4a36-9454-80d9d7e7a9ea, 7, Finished, Available, Finished)

# %%
# --------------------------
# Función utilitaria mejorada
# --------------------------
def slugify(name: str) -> str:
    # Normalizar y quitar tildes
    name = unicodedata.normalize("NFKD", name)
    name = name.encode("ascii", "ignore").decode("utf-8")  # quita acentos
    # Sustituir caracteres no válidos por "_"
    return re.sub(r'[^a-z0-9_]', '_', name.lower())
# Out:
# StatementMeta(, 692ff7bd-a54e-4a36-9454-80d9d7e7a9ea, 8, Finished, Available, Finished)

# %%
## --------------------------
# Procesamiento
# --------------------------
total_rows = 0

# Listar granularidades (day, month)
granularities = [g.name for g in mssparkutils.fs.ls(bronze_base_logical) if g.isDir]

for trunc in granularities:
    years_dirs = mssparkutils.fs.ls(f"{bronze_base_logical}/{trunc}")
    for year_dir in years_dirs:
        year = year_dir.name
        json_files = mssparkutils.fs.ls(year_dir.path)
        for f in json_files:
            if not f.path.endswith(".json"):
                continue

            print(f"\n🔎 Procesando {f.path}")

            # Leer JSON
            df_raw = spark.read.option("multiline", True).json(f.path)

            # Extraer indicador, values
            indicator_id = df_raw.select("indicator.id").first()[0]
            indicator_type = df_raw.select("indicator.short_name").first()[0] \
                              if "short_name" in df_raw.select("indicator.*").columns else indicator_id

            values = df_raw.selectExpr("explode(indicator.values) as val") \
                           .select("val.*")

            if values.rdd.isEmpty():
                print("⚠️ JSON vacío (sin values), skipping")
                continue

            # Enriquecer con metadatos
            df = (values
                  .withColumn("indicator_id", F.lit(indicator_id))
                  .withColumn("indicator_type", F.lit(indicator_type))
                  .withColumn("year", F.lit(int(year)))
                  .withColumn("time_trunc", F.lit(trunc))
                 )

            # Nombre tabla → según tipo de indicador y trunc
            indicator_slug = slugify(indicator_type)
            table_name = f"brz_esios_mercados_{indicator_slug}_{trunc}"

            # Guardar en Delta gestionado (en Lakehouse slv_lkh_esios)
            df.write.format("delta").mode("append").saveAsTable(table_name)

            count = df.count()
            total_rows += count
            print(f"✅ Guardado en tabla {table_name} ({count} registros)")

print(f"\nProceso terminado - {datetime.utcnow().isoformat()}Z")
print(f"Total registros procesados: {total_rows}")
# Out:
# StatementMeta(, 692ff7bd-a54e-4a36-9454-80d9d7e7a9ea, 9, Finished, Available, Finished)
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/day/2023/brz-mercados-mercado_spot_diario_espa_a-day-2023.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_diario_espana_day (365 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/day/2023/brz-mercados-precio_mercado_spot_diario-day-2023.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_day (2190 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/day/2023/brz-mercados-pvpc_t_2_0td-day-2023.json
# ✅ Guardado en tabla brz_esios_mercados_pvpc_t__2_0td_day (1825 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/day/2024/brz-mercados-mercado_spot_diario_espa_a-day-2024.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_diario_espana_day (366 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/day/2024/brz-mercados-precio_mercado_spot_diario-day-2024.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_day (2192 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/day/2024/brz-mercados-pvpc_t_2_0td-day-2024.json
# ✅ Guardado en tabla brz_esios_mercados_pvpc_t__2_0td_day (1830 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/day/2025/brz-mercados-mercado_spot_diario_espa_a-day-2025.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_diario_espana_day (273 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/day/2025/brz-mercados-precio_mercado_spot_diario-day-2025.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_day (1666 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/day/2025/brz-mercados-pvpc_t_2_0td-day-2025.json
# ✅ Guardado en tabla brz_esios_mercados_pvpc_t__2_0td_day (1365 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/month/2023/brz-mercados-mercado_spot_diario_espa_a-month-2023.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_diario_espana_month (12 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/month/2023/brz-mercados-precio_mercado_spot_diario-month-2023.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_month (72 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/month/2023/brz-mercados-pvpc_t_2_0td-month-2023.json
# ✅ Guardado en tabla brz_esios_mercados_pvpc_t__2_0td_month (60 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/month/2024/brz-mercados-mercado_spot_diario_espa_a-month-2024.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_diario_espana_month (12 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/month/2024/brz-mercados-precio_mercado_spot_diario-month-2024.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_month (72 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/month/2024/brz-mercados-pvpc_t_2_0td-month-2024.json
# ✅ Guardado en tabla brz_esios_mercados_pvpc_t__2_0td_month (60 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/month/2025/brz-mercados-mercado_spot_diario_espa_a-month-2025.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_diario_espana_month (9 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/month/2025/brz-mercados-precio_mercado_spot_diario-month-2025.json
# ✅ Guardado en tabla brz_esios_mercados_mercado_spot_month (56 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/mercados/componentes-precio/month/2025/brz-mercados-pvpc_t_2_0td-month-2025.json
# ✅ Guardado en tabla brz_esios_mercados_pvpc_t__2_0td_month (45 registros)
#
# Proceso terminado - 2025-10-06T12:37:43.134547Z
# Total registros procesados: 12470
