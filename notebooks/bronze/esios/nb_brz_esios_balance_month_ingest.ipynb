# %%
import requests
import json
import pandas as pd
from datetime import datetime
import os 

from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, TimestampType
# Out:
# StatementMeta(, f59feb8d-1523-4b5e-862c-b2a7d0c41f86, 3, Finished, Available, Finished)

# %%
# Iniciar Spark (en Fabric normalmente ya está disponible como spark)
spark = SparkSession.builder.getOrCreate()
# Out:
# StatementMeta(, f59feb8d-1523-4b5e-862c-b2a7d0c41f86, 4, Finished, Available, Finished)

# %%
headers = {
    "Accept": "application/json; application/vnd.esios-api-v1+json",
    "Content-Type": "application/json",
    "x-api-key": "273695bb4f30b8ab8de054a0410ee2a9d09c97a5006e3a07c27615e6c60888a7"
}
# Out:
# StatementMeta(, f59feb8d-1523-4b5e-862c-b2a7d0c41f86, 5, Finished, Available, Finished)

# %%
# 📌 Indicadores con sus nombres
indicators = [
    {"type": "hidraulica", "id": "10330"},
    {"type": "eolica", "id": "10333"},
    {"type": "solar-fotovoltaica", "id": "1707"},
    {"type": "solar-termica", "id": "1708"},
    {"type": "otras-renovables", "id": "10334"},
    {"type": "ciclo-combinado", "id": "1703"},
    {"type": "carbon", "id": "10331"},
    {"type": "cogeneracion", "id": "10335"},
    {"type": "residuos-no-renovables", "id": "10336"},
    {"type": "turbinacion-bombeo", "id": "1694"},
    {"type": "consumo-bombeo", "id": "1721"},
    {"type": "saldo-intercambios", "id": "1722"}
]

# 📆 Rango de fechas por año
date_ranges = {
    "2023": ("01-01-2023T00:00", "31-12-2023T23:55"),
    "2024": ("01-01-2024T00:00", "31-12-2024T23:55"),
    "2025": ("01-01-2025T00:00", "1-10-2025T23:55"),
}

# ⏱️ Granularidades
time_truncs = ["month"] # ["day", "month"] #solo muestra por meses
# Out:
# StatementMeta(, f59feb8d-1523-4b5e-862c-b2a7d0c41f86, 6, Finished, Available, Finished)

# %%
# 📂 Carpeta base dentro del Lakehouse (BRONZE)
base_dir = "/lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico"
# Out:
# StatementMeta(, f59feb8d-1523-4b5e-862c-b2a7d0c41f86, 7, Finished, Available, Finished)

# %%
# 🚀 Loop de descargas
for indicator in indicators:
    for year, (start_date, end_date) in date_ranges.items():
        for trunc in time_truncs:
            url = (
                f"https://api.esios.ree.es/indicators/{indicator['id']}?"
                f"start_date={start_date}&end_date={end_date}&time_trunc={trunc}"
            )
            try:
                response = requests.get(url, headers=headers, timeout=60)
                response.raise_for_status()
                data = response.json()

                # ----------------------
                # 1) Guardar JSON crudo en Files/
                # ----------------------
                filename = f"brz-balance-{indicator['type']}-{trunc}-{year}.json"
                year_dir = os.path.join(base_dir, trunc, str(year))
                os.makedirs(year_dir, exist_ok=True)
                filepath = os.path.join(year_dir, filename)

                with open(filepath, "w", encoding="utf-8") as f:
                    json.dump(data, f, ensure_ascii=False, indent=2)

                print(f"✅ Guardado JSON en Lakehouse: {filepath}")

            except requests.exceptions.RequestException as e:
                print(f"❌ Error en {url}: {e}")

print(f"\nProceso terminado - {datetime.utcnow().isoformat()}Z")
# Out:
# StatementMeta(, f59feb8d-1523-4b5e-862c-b2a7d0c41f86, 8, Finished, Available, Finished)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-hidraulica-month-2023.json
# ✅ Guardado en Tables/brz_balance_hidraulica_month (192 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-hidraulica-month-2024.json
# ✅ Guardado en Tables/brz_balance_hidraulica_month (192 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-hidraulica-month-2025.json
# ✅ Guardado en Tables/brz_balance_hidraulica_month (62 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-eolica-month-2023.json
# ✅ Guardado en Tables/brz_balance_eolica_month (190 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-eolica-month-2024.json
# ✅ Guardado en Tables/brz_balance_eolica_month (180 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-eolica-month-2025.json
# ✅ Guardado en Tables/brz_balance_eolica_month (60 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-solar-fotovoltaica-month-2023.json
# ✅ Guardado en Tables/brz_balance_solar-fotovoltaica_month (220 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-solar-fotovoltaica-month-2024.json
# ✅ Guardado en Tables/brz_balance_solar-fotovoltaica_month (224 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-solar-fotovoltaica-month-2025.json
# ✅ Guardado en Tables/brz_balance_solar-fotovoltaica_month (71 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-solar-termica-month-2023.json
# ✅ Guardado en Tables/brz_balance_solar-termica_month (72 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-solar-termica-month-2024.json
# ✅ Guardado en Tables/brz_balance_solar-termica_month (72 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-solar-termica-month-2025.json
# ✅ Guardado en Tables/brz_balance_solar-termica_month (24 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-otras-renovables-month-2023.json
# ✅ Guardado en Tables/brz_balance_otras-renovables_month (204 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-otras-renovables-month-2024.json
# ✅ Guardado en Tables/brz_balance_otras-renovables_month (204 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-otras-renovables-month-2025.json
# ✅ Guardado en Tables/brz_balance_otras-renovables_month (68 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-ciclo-combinado-month-2023.json
# ✅ Guardado en Tables/brz_balance_ciclo-combinado_month (155 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-ciclo-combinado-month-2024.json
# ✅ Guardado en Tables/brz_balance_ciclo-combinado_month (156 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-ciclo-combinado-month-2025.json
# ✅ Guardado en Tables/brz_balance_ciclo-combinado_month (52 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-carbon-month-2023.json
# ✅ Guardado en Tables/brz_balance_carbon_month (31 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-carbon-month-2024.json
# ✅ Guardado en Tables/brz_balance_carbon_month (20 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-carbon-month-2025.json
# ✅ Guardado en Tables/brz_balance_carbon_month (9 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-cogeneracion-month-2023.json
# ✅ Guardado en Tables/brz_balance_cogeneracion_month (192 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-cogeneracion-month-2024.json
# ✅ Guardado en Tables/brz_balance_cogeneracion_month (192 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-cogeneracion-month-2025.json
# ✅ Guardado en Tables/brz_balance_cogeneracion_month (64 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-residuos-no-renovables-month-2023.json
# ✅ Guardado en Tables/brz_balance_residuos-no-renovables_month (131 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-residuos-no-renovables-month-2024.json
# ✅ Guardado en Tables/brz_balance_residuos-no-renovables_month (131 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-residuos-no-renovables-month-2025.json
# ✅ Guardado en Tables/brz_balance_residuos-no-renovables_month (44 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-turbinacion-bombeo-month-2023.json
# ✅ Guardado en Tables/brz_balance_turbinacion-bombeo_month (120 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-turbinacion-bombeo-month-2024.json
# ✅ Guardado en Tables/brz_balance_turbinacion-bombeo_month (120 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-turbinacion-bombeo-month-2025.json
# ✅ Guardado en Tables/brz_balance_turbinacion-bombeo_month (40 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-consumo-bombeo-month-2023.json
# ✅ Guardado en Tables/brz_balance_consumo-bombeo_month (120 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-consumo-bombeo-month-2024.json
# ✅ Guardado en Tables/brz_balance_consumo-bombeo_month (120 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-consumo-bombeo-month-2025.json
# ✅ Guardado en Tables/brz_balance_consumo-bombeo_month (40 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-saldo-intercambios-month-2023.json
# ✅ Guardado en Tables/brz_balance_saldo-intercambios_month (192 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-saldo-intercambios-month-2024.json
# ✅ Guardado en Tables/brz_balance_saldo-intercambios_month (192 registros)
# ✅ Guardado JSON en Lakehouse: /lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-saldo-intercambios-month-2025.json
# ✅ Guardado en Tables/brz_balance_saldo-intercambios_month (64 registros)
#
# Proceso terminado - 2025-09-29T22:18:20.747717Z
