# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import (
    col, when, desc, lit,
    count as spark_count,
    min as spark_min,
    max as spark_max
)
from pyspark.sql.types import *
import pandas as pd
# Out:
# StatementMeta(, 9d1c3a59-d18e-4fdf-8498-c7eee8f1135d, 3, Finished, Available, Finished)

# %%
spark = SparkSession.builder.appName("Bronze_Exploration").getOrCreate()
# Out:
# StatementMeta(, 9d1c3a59-d18e-4fdf-8498-c7eee8f1135d, 4, Finished, Available, Finished)

# %%
# Lista de tablas a analizar
tables = [
    "brz_redata_balance_balance_electrico",
    "brz_redata_demanda_evolucion",
    "brz_redata_generacion_estructura_generacion",
    "brz_redata_generacion_estructura_generacion_emisiones_asociadas",
    "brz_redata_generacion_estructura_renovables",
    "brz_redata_generacion_evolucion_renovable_no_renovable",
    "brz_redata_generacion_maxima_renovable",
    "brz_redata_mercados_componentes_precio"
]
# Out:
# StatementMeta(, 9d1c3a59-d18e-4fdf-8498-c7eee8f1135d, 5, Finished, Available, Finished)

# %%
# ============================================
# 1. RESUMEN GENERAL DE TODAS LAS TABLAS
# ============================================
print("\n📊 1. RESUMEN GENERAL")
print("-" * 80)

summary_data = []
for table in tables:
    df = spark.table(table)
    row_count = df.count()
    cols = len(df.columns)
    min_date = df.agg(spark_min("datetime")).collect()[0][0]
    max_date = df.agg(spark_max("datetime")).collect()[0][0]
    
    summary_data.append({
        "tabla": table.replace("brz_redata_", ""),
        "registros": f"{row_count:,}",
        "columnas": cols,
        "fecha_min": str(min_date)[:10] if min_date else "N/A",
        "fecha_max": str(max_date)[:10] if max_date else "N/A"
    })
    
summary_df = pd.DataFrame(summary_data)
print(summary_df.to_string(index=False))
# Out:
# StatementMeta(, 9d1c3a59-d18e-4fdf-8498-c7eee8f1135d, 6, Finished, Available, Finished)
# 📊 1. RESUMEN GENERAL
# --------------------------------------------------------------------------------
#                                                tabla registros  columnas  fecha_min  fecha_max
#                            balance_balance_electrico    74,858        14 2023-09-30 2025-09-30
#                                    demanda_evolucion     6,381        14 2023-09-30 2025-09-30
#                     generacion_estructura_generacion    49,653        14 2023-09-30 2025-09-30
# generacion_estructura_generacion_emisiones_asociadas    43,028        14 2023-09-30 2025-09-30
#                     generacion_estructura_renovables    27,008        14 2023-09-30 2025-09-30
#          generacion_evolucion_renovable_no_renovable    11,935        14 2023-09-30 2025-09-30
#                          generacion_maxima_renovable       173        14 2023-09-30 2025-09-30
#                          mercados_componentes_precio       156        14 2023-09-30 2025-09-30

# %%
# ============================================
# 2. ANÁLISIS DETALLADO POR TABLA
# ============================================
print("\n" + "=" * 80)
print("📋 2. ANÁLISIS DETALLADO POR TABLA")
print("=" * 80)

for table in tables:
    print(f"\n{'─' * 80}")
    print(f"📦 {table}")
    print(f"{'─' * 80}")
    
    df = spark.table(table)
    
    # Schema
    print("\n🔹 Schema:")
    df.printSchema()
    
    # Conteos por dimensiones clave
    print("\n🔹 Distribución por geo_limit:")
    df.groupBy("geo_limit").agg(spark_count("*").alias("count")).orderBy(desc("count")).show(10, truncate=False)
    
    print("🔹 Distribución por time_trunc:")
    df.groupBy("time_trunc").agg(spark_count("*").alias("count")).orderBy(desc("count")).show(10, truncate=False)
    
    # Valores únicos en columnas clave
    print(f"🔹 Valores únicos:")
    print(f"  - geo_id: {df.select('geo_id').distinct().count()}")
    print(f"  - geo_name: {df.select('geo_name').distinct().count()}")
    print(f"  - series_type: {df.select('series_type').distinct().count()}")
    print(f"  - metric_type: {df.select('metric_type').distinct().count()}")
    
    # Nulls
    print("\n🔹 Análisis de nulos:")
    null_counts = df.select([
        spark_count(when(col(c).isNull(), c)).alias(c) 
        for c in df.columns
    ]).collect()[0].asDict()
    
    nulls_found = {k: v for k, v in null_counts.items() if v > 0}
    if nulls_found:
        for col_name, null_count in nulls_found.items():
            pct = (null_count / df.count()) * 100
            print(f"  - {col_name}: {null_count:,} ({pct:.2f}%)")
    else:
        print("  ✅ Sin nulos en columnas principales")
    
    # Muestra de series disponibles
    print("\n🔹 Series disponibles (top 5):")
    df.select("series_title", "metric_title") \
      .distinct() \
      .limit(5) \
      .show(5, truncate=False)
    
    # Rango temporal detallado
    print("🔹 Cobertura temporal:")
    temporal = df.groupBy("time_trunc") \
                 .agg(
                     spark_min("datetime").alias("fecha_inicio"),
                     spark_max("datetime").alias("fecha_fin"),
                     spark_count("*").alias("registros")
                 ) \
                 .orderBy("time_trunc")
    temporal.show(truncate=False)
    
    # Detectar posibles duplicados
    print("🔹 Verificación de duplicados:")
    total = df.count()
    unique = df.dropDuplicates(["geo_id", "time_trunc", "series_type", "datetime"]).count()
    if total == unique:
        print(f"  ✅ Sin duplicados ({total:,} registros únicos)")
    else:
        print(f"  ⚠️ Posibles duplicados: {total - unique:,} registros")
# Out:
# StatementMeta(, 9d1c3a59-d18e-4fdf-8498-c7eee8f1135d, 7, Finished, Available, Finished)
# ================================================================================
# 📋 2. ANÁLISIS DETALLADO POR TABLA
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_balance_balance_electrico
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Schema:
# root
#  |-- geo_id: long (nullable = true)
#  |-- geo_name: string (nullable = true)
#  |-- geo_limit: string (nullable = true)
#  |-- ccaa_name: string (nullable = true)
#  |-- time_trunc: string (nullable = true)
#  |-- series_type: string (nullable = true)
#  |-- series_title: string (nullable = true)
#  |-- metric_type: string (nullable = true)
#  |-- metric_title: string (nullable = true)
#  |-- is_composite: boolean (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- value: double (nullable = true)
#  |-- percentage: double (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#
#
# 🔹 Distribución por geo_limit:
# +----------+-----+
# |geo_limit |count|
# +----------+-----+
# |peninsular|24278|
# |baleares  |16084|
# |canarias  |13627|
# |ccaa      |8726 |
# |melilla   |7919 |
# |ceuta     |4224 |
# +----------+-----+
#
# 🔹 Distribución por time_trunc:
# +----------+-----+
# |time_trunc|count|
# +----------+-----+
# |day       |63774|
# |month     |11084|
# +----------+-----+
#
# 🔹 Valores únicos:
#   - geo_id: 20
#   - geo_name: 20
#   - series_type: 4
#   - metric_type: 27
#
# 🔹 Análisis de nulos:
#   - ccaa_name: 66,132 (88.34%)
#
# 🔹 Series disponibles (top 5):
# +------------+------------------------+
# |series_title|metric_title            |
# +------------+------------------------+
# |Demanda     |Saldo I. internacionales|
# |No-Renovable|Ciclo combinado         |
# |Renovable   |Hidroeólica             |
# |No-Renovable|Carbón                  |
# |Renovable   |Residuos renovables     |
# +------------+------------------------+
#
# 🔹 Cobertura temporal:
# +----------+-------------------+-------------------+---------+
# |time_trunc|fecha_inicio       |fecha_fin          |registros|
# +----------+-------------------+-------------------+---------+
# |day       |2023-09-30 22:00:00|2025-09-30 22:00:00|63774    |
# |month     |2023-09-30 22:00:00|2025-09-30 22:00:00|11084    |
# +----------+-------------------+-------------------+---------+
#
# 🔹 Verificación de duplicados:
#   ⚠️ Posibles duplicados: 61,540 registros
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_demanda_evolucion
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Schema:
# root
#  |-- geo_id: long (nullable = true)
#  |-- geo_name: string (nullable = true)
#  |-- geo_limit: string (nullable = true)
#  |-- ccaa_name: string (nullable = true)
#  |-- time_trunc: string (nullable = true)
#  |-- series_type: string (nullable = true)
#  |-- series_title: string (nullable = true)
#  |-- metric_type: string (nullable = true)
#  |-- metric_title: string (nullable = true)
#  |-- is_composite: boolean (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- value: double (nullable = true)
#  |-- percentage: double (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#
#
# 🔹 Distribución por geo_limit:
# +----------+-----+
# |geo_limit |count|
# +----------+-----+
# |ceuta     |1140 |
# |baleares  |1140 |
# |canarias  |1140 |
# |peninsular|1140 |
# |melilla   |1140 |
# |ccaa      |681  |
# +----------+-----+
#
# 🔹 Distribución por time_trunc:
# +----------+-----+
# |time_trunc|count|
# +----------+-----+
# |day       |5505 |
# |month     |876  |
# +----------+-----+
#
# 🔹 Valores únicos:
#   - geo_id: 20
#   - geo_name: 20
#   - series_type: 1
#   - metric_type: 1
#
# 🔹 Análisis de nulos:
#   - ccaa_name: 5,700 (89.33%)
#   - metric_type: 6,381 (100.00%)
#
# 🔹 Series disponibles (top 5):
# +------------+------------+
# |series_title|metric_title|
# +------------+------------+
# |Demanda     |Demanda     |
# +------------+------------+
#
# 🔹 Cobertura temporal:
# +----------+-------------------+-------------------+---------+
# |time_trunc|fecha_inicio       |fecha_fin          |registros|
# +----------+-------------------+-------------------+---------+
# |day       |2023-09-30 22:00:00|2025-09-30 22:00:00|5505     |
# |month     |2023-09-30 22:00:00|2025-09-30 22:00:00|876      |
# +----------+-------------------+-------------------+---------+
#
# 🔹 Verificación de duplicados:
#   ⚠️ Posibles duplicados: 2,281 registros
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_estructura_generacion
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Schema:
# root
#  |-- geo_id: long (nullable = true)
#  |-- geo_name: string (nullable = true)
#  |-- geo_limit: string (nullable = true)
#  |-- ccaa_name: string (nullable = true)
#  |-- time_trunc: string (nullable = true)
#  |-- series_type: string (nullable = true)
#  |-- series_title: string (nullable = true)
#  |-- metric_type: string (nullable = true)
#  |-- metric_title: string (nullable = true)
#  |-- is_composite: boolean (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- value: double (nullable = true)
#  |-- percentage: double (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#
#
# 🔹 Distribución por geo_limit:
# +----------+-----+
# |geo_limit |count|
# +----------+-----+
# |peninsular|13898|
# |canarias  |11287|
# |baleares  |10573|
# |melilla   |5649 |
# |ccaa      |5496 |
# |ceuta     |2750 |
# +----------+-----+
#
# 🔹 Distribución por time_trunc:
# +----------+-----+
# |time_trunc|count|
# +----------+-----+
# |day       |42576|
# |month     |7077 |
# +----------+-----+
#
# 🔹 Valores únicos:
#   - geo_id: 20
#   - geo_name: 20
#   - series_type: 17
#   - metric_type: 3
#
# 🔹 Análisis de nulos:
#   - ccaa_name: 44,157 (88.93%)
#
# 🔹 Series disponibles (top 5):
# +----------------------+----------------------+
# |series_title          |metric_title          |
# +----------------------+----------------------+
# |Eólica                |Eólica                |
# |Otras renovables      |Otras renovables      |
# |Hidroeólica           |Hidroeólica           |
# |Residuos no renovables|Residuos no renovables|
# |Ciclo combinado       |Ciclo combinado       |
# +----------------------+----------------------+
#
# 🔹 Cobertura temporal:
# +----------+-------------------+-------------------+---------+
# |time_trunc|fecha_inicio       |fecha_fin          |registros|
# +----------+-------------------+-------------------+---------+
# |day       |2023-09-30 22:00:00|2025-09-30 22:00:00|42576    |
# |month     |2023-09-30 22:00:00|2025-09-30 22:00:00|7077     |
# +----------+-------------------+-------------------+---------+
#
# 🔹 Verificación de duplicados:
#   ⚠️ Posibles duplicados: 18,252 registros
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_estructura_generacion_emisiones_asociadas
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Schema:
# root
#  |-- geo_id: long (nullable = true)
#  |-- geo_name: string (nullable = true)
#  |-- geo_limit: string (nullable = true)
#  |-- ccaa_name: string (nullable = true)
#  |-- time_trunc: string (nullable = true)
#  |-- series_type: string (nullable = true)
#  |-- series_title: string (nullable = true)
#  |-- metric_type: string (nullable = true)
#  |-- metric_title: string (nullable = true)
#  |-- is_composite: boolean (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- value: double (nullable = true)
#  |-- percentage: double (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#
#
# 🔹 Distribución por geo_limit:
# +----------+-----+
# |geo_limit |count|
# +----------+-----+
# |peninsular|12698|
# |canarias  |10087|
# |baleares  |9373 |
# |ccaa      |4815 |
# |melilla   |4449 |
# |ceuta     |1606 |
# +----------+-----+
#
# 🔹 Distribución por time_trunc:
# +----------+-----+
# |time_trunc|count|
# +----------+-----+
# |day       |36827|
# |month     |6201 |
# +----------+-----+
#
# 🔹 Valores únicos:
#   - geo_id: 20
#   - geo_name: 20
#   - series_type: 16
#   - metric_type: 2
#
# 🔹 Análisis de nulos:
#   - ccaa_name: 38,213 (88.81%)
#
# 🔹 Series disponibles (top 5):
# +----------------------+----------------------+
# |series_title          |metric_title          |
# +----------------------+----------------------+
# |Eólica                |Eólica                |
# |Otras renovables      |Otras renovables      |
# |Hidroeólica           |Hidroeólica           |
# |Residuos no renovables|Residuos no renovables|
# |Ciclo combinado       |Ciclo combinado       |
# +----------------------+----------------------+
#
# 🔹 Cobertura temporal:
# +----------+-------------------+-------------------+---------+
# |time_trunc|fecha_inicio       |fecha_fin          |registros|
# +----------+-------------------+-------------------+---------+
# |day       |2023-09-30 22:00:00|2025-09-30 22:00:00|36827    |
# |month     |2023-09-30 22:00:00|2025-09-30 22:00:00|6201     |
# +----------+-------------------+-------------------+---------+
#
# 🔹 Verificación de duplicados:
#   ⚠️ Posibles duplicados: 15,727 registros
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_estructura_renovables
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Schema:
# root
#  |-- geo_id: long (nullable = true)
#  |-- geo_name: string (nullable = true)
#  |-- geo_limit: string (nullable = true)
#  |-- ccaa_name: string (nullable = true)
#  |-- time_trunc: string (nullable = true)
#  |-- series_type: string (nullable = true)
#  |-- series_title: string (nullable = true)
#  |-- metric_type: string (nullable = true)
#  |-- metric_title: string (nullable = true)
#  |-- is_composite: boolean (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- value: double (nullable = true)
#  |-- percentage: double (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#
#
# 🔹 Distribución por geo_limit:
# +----------+-----+
# |geo_limit |count|
# +----------+-----+
# |peninsular|8100 |
# |canarias  |6675 |
# |baleares  |4671 |
# |ccaa      |3523 |
# |melilla   |3371 |
# |ceuta     |668  |
# +----------+-----+
#
# 🔹 Distribución por time_trunc:
# +----------+-----+
# |time_trunc|count|
# +----------+-----+
# |day       |22664|
# |month     |4344 |
# +----------+-----+
#
# 🔹 Valores únicos:
#   - geo_id: 20
#   - geo_name: 20
#   - series_type: 8
#   - metric_type: 3
#
# 🔹 Análisis de nulos:
#   - ccaa_name: 23,485 (86.96%)
#   - metric_type: 20,055 (74.26%)
#
# 🔹 Series disponibles (top 5):
# +--------------------+--------------------+
# |series_title        |metric_title        |
# +--------------------+--------------------+
# |Eólica              |Eólica              |
# |Generación renovable|Generación renovable|
# |Otras renovables    |Otras renovables    |
# |Hidroeólica         |Hidroeólica         |
# |Residuos renovables |Residuos renovables |
# +--------------------+--------------------+
#
# 🔹 Cobertura temporal:
# +----------+-------------------+-------------------+---------+
# |time_trunc|fecha_inicio       |fecha_fin          |registros|
# +----------+-------------------+-------------------+---------+
# |day       |2023-09-30 22:00:00|2025-09-30 22:00:00|22664    |
# |month     |2023-09-30 22:00:00|2025-09-30 22:00:00|4344     |
# +----------+-------------------+-------------------+---------+
#
# 🔹 Verificación de duplicados:
#   ⚠️ Posibles duplicados: 10,114 registros
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_evolucion_renovable_no_renovable
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Schema:
# root
#  |-- geo_id: long (nullable = true)
#  |-- geo_name: string (nullable = true)
#  |-- geo_limit: string (nullable = true)
#  |-- ccaa_name: string (nullable = true)
#  |-- time_trunc: string (nullable = true)
#  |-- series_type: string (nullable = true)
#  |-- series_title: string (nullable = true)
#  |-- metric_type: string (nullable = true)
#  |-- metric_title: string (nullable = true)
#  |-- is_composite: boolean (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- value: double (nullable = true)
#  |-- percentage: double (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#
#
# 🔹 Distribución por geo_limit:
# +----------+-----+
# |geo_limit |count|
# +----------+-----+
# |baleares  |2280 |
# |canarias  |2280 |
# |peninsular|2280 |
# |melilla   |2270 |
# |ceuta     |1474 |
# |ccaa      |1351 |
# +----------+-----+
#
# 🔹 Distribución por time_trunc:
# +----------+-----+
# |time_trunc|count|
# +----------+-----+
# |day       |10205|
# |month     |1730 |
# +----------+-----+
#
# 🔹 Valores únicos:
#   - geo_id: 20
#   - geo_name: 20
#   - series_type: 2
#   - metric_type: 2
#
# 🔹 Análisis de nulos:
#   - ccaa_name: 10,584 (88.68%)
#
# 🔹 Series disponibles (top 5):
# +------------+------------+
# |series_title|metric_title|
# +------------+------------+
# |No renovable|No renovable|
# |Renovable   |Renovable   |
# +------------+------------+
#
# 🔹 Cobertura temporal:
# +----------+-------------------+-------------------+---------+
# |time_trunc|fecha_inicio       |fecha_fin          |registros|
# +----------+-------------------+-------------------+---------+
# |day       |2023-09-30 22:00:00|2025-09-30 22:00:00|10205    |
# |month     |2023-09-30 22:00:00|2025-09-30 22:00:00|1730     |
# +----------+-------------------+-------------------+---------+
#
# 🔹 Verificación de duplicados:
#   ⚠️ Posibles duplicados: 4,310 registros
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_maxima_renovable
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Schema:
# root
#  |-- geo_id: long (nullable = true)
#  |-- geo_name: string (nullable = true)
#  |-- geo_limit: string (nullable = true)
#  |-- ccaa_name: string (nullable = true)
#  |-- time_trunc: string (nullable = true)
#  |-- series_type: string (nullable = true)
#  |-- series_title: string (nullable = true)
#  |-- metric_type: string (nullable = true)
#  |-- metric_title: string (nullable = true)
#  |-- is_composite: boolean (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- value: double (nullable = true)
#  |-- percentage: double (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#
#
# 🔹 Distribución por geo_limit:
# +----------+-----+
# |geo_limit |count|
# +----------+-----+
# |baleares  |37   |
# |melilla   |36   |
# |peninsular|36   |
# |canarias  |36   |
# |ceuta     |28   |
# +----------+-----+
#
# 🔹 Distribución por time_trunc:
# +----------+-----+
# |time_trunc|count|
# +----------+-----+
# |month     |173  |
# +----------+-----+
#
# 🔹 Valores únicos:
#   - geo_id: 5
#   - geo_name: 5
#   - series_type: 1
#   - metric_type: 1
#
# 🔹 Análisis de nulos:
#   - ccaa_name: 173 (100.00%)
#   - metric_type: 173 (100.00%)
#
# 🔹 Series disponibles (top 5):
# +---------------------------+---------------------------+
# |series_title               |metric_title               |
# +---------------------------+---------------------------+
# |Máxima generación renovable|Máxima generación renovable|
# +---------------------------+---------------------------+
#
# 🔹 Cobertura temporal:
# +----------+-------------------+-------------------+---------+
# |time_trunc|fecha_inicio       |fecha_fin          |registros|
# +----------+-------------------+-------------------+---------+
# |month     |2023-09-30 22:00:00|2025-09-30 22:00:00|173      |
# +----------+-------------------+-------------------+---------+
#
# 🔹 Verificación de duplicados:
#   ⚠️ Posibles duplicados: 59 registros
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_mercados_componentes_precio
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Schema:
# root
#  |-- geo_id: long (nullable = true)
#  |-- geo_name: string (nullable = true)
#  |-- geo_limit: string (nullable = true)
#  |-- ccaa_name: string (nullable = true)
#  |-- time_trunc: string (nullable = true)
#  |-- series_type: string (nullable = true)
#  |-- series_title: string (nullable = true)
#  |-- metric_type: string (nullable = true)
#  |-- metric_title: string (nullable = true)
#  |-- is_composite: boolean (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- value: double (nullable = true)
#  |-- percentage: double (nullable = true)
#  |-- ingestion_timestamp: timestamp (nullable = true)
#
#
# 🔹 Distribución por geo_limit:
# +----------+-----+
# |geo_limit |count|
# +----------+-----+
# |peninsular|156  |
# +----------+-----+
#
# 🔹 Distribución por time_trunc:
# +----------+-----+
# |time_trunc|count|
# +----------+-----+
# |month     |156  |
# +----------+-----+
#
# 🔹 Valores únicos:
#   - geo_id: 1
#   - geo_name: 1
#   - series_type: 6
#   - metric_type: 3
#
# 🔹 Análisis de nulos:
#   - ccaa_name: 156 (100.00%)
#   - metric_type: 104 (66.67%)
#
# 🔹 Series disponibles (top 5):
# +--------------------------+--------------------------+
# |series_title              |metric_title              |
# +--------------------------+--------------------------+
# |Mercado diario            |Mercado diario            |
# |Pagos por capacidad       |Pagos por capacidad       |
# |Servicios de ajuste       |Servicios de ajuste       |
# |distinct                  |distinct                  |
# |Servicio interrumpibilidad|Servicio interrumpibilidad|
# +--------------------------+--------------------------+
#
# 🔹 Cobertura temporal:
# +----------+-------------------+-------------------+---------+
# |time_trunc|fecha_inicio       |fecha_fin          |registros|
# +----------+-------------------+-------------------+---------+
# |month     |2023-09-30 22:00:00|2025-09-30 22:00:00|156      |
# +----------+-------------------+-------------------+---------+
#
# 🔹 Verificación de duplicados:
#   ⚠️ Posibles duplicados: 6 registros

# %%
# ============================================
# 3. ANÁLISIS DE VALORES Y RANGOS
# ============================================
print("\n" + "=" * 80)
print("📈 3. ANÁLISIS DE VALORES")
print("=" * 80)

for table in tables:
    print(f"\n{'─' * 80}")
    print(f"📦 {table}")
    print(f"{'─' * 80}")
    
    df = spark.table(table)
    
    # Stats de valores
    print("\n🔹 Estadísticas de 'value':")
    df.select("value").summary("count", "mean", "stddev", "min", "max").show(truncate=False)
    
    # Porcentajes (si existen)
    if "percentage" in df.columns:
        non_null_pct = df.filter(col("percentage").isNotNull()).count()
        if non_null_pct > 0:
            print("🔹 Estadísticas de 'percentage':")
            df.filter(col("percentage").isNotNull()) \
              .select("percentage") \
              .summary("count", "mean", "min", "max") \
              .show(truncate=False)
    
    # Valores extremos o anómalos
    print("🔹 Top 5 valores máximos:")
    df.orderBy(desc("value")) \
      .select("datetime", "geo_name", "series_title", "value") \
      .limit(5) \
      .show(5, truncate=False)
# Out:
# StatementMeta(, 9d1c3a59-d18e-4fdf-8498-c7eee8f1135d, 8, Finished, Available, Finished)
# ================================================================================
# 📈 3. ANÁLISIS DE VALORES
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_balance_balance_electrico
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Estadísticas de 'value':
# +-------+--------------------+
# |summary|value               |
# +-------+--------------------+
# |count  |74858               |
# |mean   |90730.5399486361    |
# |stddev |623420.7797951947   |
# |min    |-3106069.988        |
# |max    |2.1907194242999997E7|
# +-------+--------------------+
#
# 🔹 Estadísticas de 'percentage':
# +-------+----------------------+
# |summary|percentage            |
# +-------+----------------------+
# |count  |74858                 |
# |mean   |0.49231087379325905   |
# |min    |1.0194169977452991E-10|
# |max    |1.0                   |
# +-------+----------------------+
#
# 🔹 Top 5 valores máximos:
# +-------------------+---------+------------+--------------------+
# |datetime           |geo_name |series_title|value               |
# +-------------------+---------+------------+--------------------+
# |2025-06-30 22:00:00|Península|Demanda     |2.1907194242999997E7|
# |2024-12-31 23:00:00|Península|Demanda     |2.1683816453999996E7|
# |2024-06-30 22:00:00|Península|Demanda     |2.1283278634999998E7|
# |2024-06-30 22:00:00|Península|Demanda     |2.1283278634999998E7|
# |2023-12-31 23:00:00|Península|Demanda     |2.1122754698999997E7|
# +-------------------+---------+------------+--------------------+
#
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_demanda_evolucion
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Estadísticas de 'value':
# +-------+------------------+
# |summary|value             |
# +-------+------------------+
# |count  |6381              |
# |mean   |349163.0717050623 |
# |stddev |1533845.2641238978|
# |min    |19.131            |
# |max    |2.19071942429999E7|
# +-------+------------------+
#
# 🔹 Estadísticas de 'percentage':
# +-------+----------+
# |summary|percentage|
# +-------+----------+
# |count  |6381      |
# |mean   |1.0       |
# |min    |1.0       |
# |max    |1.0       |
# +-------+----------+
#
# 🔹 Top 5 valores máximos:
# +-------------------+---------+------------+------------------+
# |datetime           |geo_name |series_title|value             |
# +-------------------+---------+------------+------------------+
# |2025-06-30 22:00:00|Península|Demanda     |2.19071942429999E7|
# |2024-12-31 23:00:00|Península|Demanda     |2.1683816454E7    |
# |2024-06-30 22:00:00|Península|Demanda     |2.1283278635E7    |
# |2024-06-30 22:00:00|Península|Demanda     |2.1283278635E7    |
# |2023-12-31 23:00:00|Península|Demanda     |2.1122754699E7    |
# +-------------------+---------+------------+------------------+
#
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_estructura_generacion
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Estadísticas de 'value':
# +-------+-----------------+
# |summary|value            |
# +-------+-----------------+
# |count  |49653            |
# |mean   |95067.98035079526|
# |stddev |651252.3771361   |
# |min    |-166.5           |
# |max    |2.3783934455E7   |
# +-------+-----------------+
#
# 🔹 Estadísticas de 'percentage':
# +-------+----------------------+
# |summary|percentage            |
# +-------+----------------------+
# |count  |49653                 |
# |mean   |0.28971275806323565   |
# |min    |4.6055715867821426E-11|
# |max    |1.0                   |
# +-------+----------------------+
#
# 🔹 Top 5 valores máximos:
# +-------------------+---------+----------------+--------------------+
# |datetime           |geo_name |series_title    |value               |
# +-------------------+---------+----------------+--------------------+
# |2025-06-30 22:00:00|Península|Generación total|2.3783934455E7      |
# |2024-12-31 23:00:00|Península|Generación total|2.3200606161000002E7|
# |2025-02-28 23:00:00|Península|Generación total|2.2644361703999996E7|
# |2024-06-30 22:00:00|Península|Generación total|2.2643097143000003E7|
# |2024-06-30 22:00:00|Península|Generación total|2.2643097143000003E7|
# +-------------------+---------+----------------+--------------------+
#
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_estructura_generacion_emisiones_asociadas
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Estadísticas de 'value':
# +-------+------------------+
# |summary|value             |
# +-------+------------------+
# |count  |43028             |
# |mean   |54852.775266779914|
# |stddev |283330.33780777635|
# |min    |-166.5            |
# |max    |7495043.433       |
# +-------+------------------+
#
# 🔹 Estadísticas de 'percentage':
# +-------+----------------------+
# |summary|percentage            |
# +-------+----------------------+
# |count  |43028                 |
# |mean   |0.18035018072217732   |
# |min    |4.6055715867821426E-11|
# |max    |1.0                   |
# +-------+----------------------+
#
# 🔹 Top 5 valores máximos:
# +-------------------+---------+------------+-----------+
# |datetime           |geo_name |series_title|value      |
# +-------------------+---------+------------+-----------+
# |2024-12-31 23:00:00|Península|Eólica      |7495043.433|
# |2023-10-31 23:00:00|Península|Eólica      |6906465.373|
# |2023-10-31 23:00:00|Península|Eólica      |6906465.373|
# |2024-01-31 23:00:00|Península|Eólica      |6853210.703|
# |2024-01-31 23:00:00|Península|Eólica      |6853210.703|
# +-------------------+---------+------------+-----------+
#
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_estructura_renovables
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Estadísticas de 'value':
# +-------+-----------------+
# |summary|value            |
# +-------+-----------------+
# |count  |27008            |
# |mean   |99879.20738721872|
# |stddev |557856.587570001 |
# |min    |0.001            |
# |max    |1.437166277E7    |
# +-------+-----------------+
#
# 🔹 Estadísticas de 'percentage':
# +-------+--------------------+
# |summary|percentage          |
# +-------+--------------------+
# |count  |27008               |
# |mean   |0.43183501184834233 |
# |min    |2.421895339956444E-7|
# |max    |1.0                 |
# +-------+--------------------+
#
# 🔹 Top 5 valores máximos:
# +-------------------+---------+--------------------+--------------------+
# |datetime           |geo_name |series_title        |value               |
# +-------------------+---------+--------------------+--------------------+
# |2025-02-28 23:00:00|Península|Generación renovable|1.437166277E7       |
# |2024-02-29 23:00:00|Península|Generación renovable|1.4290599253500002E7|
# |2024-02-29 23:00:00|Península|Generación renovable|1.4290599253500002E7|
# |2025-06-30 22:00:00|Península|Generación renovable|1.3547919651999999E7|
# |2024-03-31 22:00:00|Península|Generación renovable|1.3410309466999998E7|
# +-------------------+---------+--------------------+--------------------+
#
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_evolucion_renovable_no_renovable
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Estadísticas de 'value':
# +-------+------------------+
# |summary|value             |
# +-------+------------------+
# |count  |11935             |
# |mean   |197182.27590967744|
# |stddev |874830.2345799651 |
# |min    |0.001             |
# |max    |1.437166277E7     |
# +-------+------------------+
#
# 🔹 Estadísticas de 'percentage':
# +-------+--------------------+
# |summary|percentage          |
# +-------+--------------------+
# |count  |11935               |
# |mean   |0.5495601173020519  |
# |min    |6.448009921681827E-8|
# |max    |1.0                 |
# +-------+--------------------+
#
# 🔹 Top 5 valores máximos:
# +-------------------+---------+------------+---------------+
# |datetime           |geo_name |series_title|value          |
# +-------------------+---------+------------+---------------+
# |2025-02-28 23:00:00|Península|Renovable   |1.437166277E7  |
# |2024-02-29 23:00:00|Península|Renovable   |1.42905992535E7|
# |2024-02-29 23:00:00|Península|Renovable   |1.42905992535E7|
# |2025-06-30 22:00:00|Península|Renovable   |1.3547919652E7 |
# |2024-03-31 22:00:00|Península|Renovable   |1.3410309467E7 |
# +-------------------+---------+------------+---------------+
#
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_generacion_maxima_renovable
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Estadísticas de 'value':
# +-------+------------------+
# |summary|value             |
# +-------+------------------+
# |count  |173               |
# |mean   |110373.31733526012|
# |stddev |211120.70603995922|
# |min    |0.001             |
# |max    |582380.686        |
# +-------+------------------+
#
# 🔹 Estadísticas de 'percentage':
# +-------+----------+
# |summary|percentage|
# +-------+----------+
# |count  |173       |
# |mean   |1.0       |
# |min    |1.0       |
# |max    |1.0       |
# +-------+----------+
#
# 🔹 Top 5 valores máximos:
# +-------------------+---------+---------------------------+----------+
# |datetime           |geo_name |series_title               |value     |
# +-------------------+---------+---------------------------+----------+
# |2025-03-19 23:00:00|Península|Máxima generación renovable|582380.686|
# |2024-01-16 23:00:00|Península|Máxima generación renovable|575588.256|
# |2024-01-16 23:00:00|Península|Máxima generación renovable|575588.256|
# |2024-02-22 23:00:00|Península|Máxima generación renovable|570032.339|
# |2024-02-22 23:00:00|Península|Máxima generación renovable|570032.339|
# +-------------------+---------+---------------------------+----------+
#
#
# ────────────────────────────────────────────────────────────────────────────────
# 📦 brz_redata_mercados_componentes_precio
# ────────────────────────────────────────────────────────────────────────────────
#
# 🔹 Estadísticas de 'value':
# +-------+------------------+
# |summary|value             |
# +-------+------------------+
# |count  |156               |
# |mean   |25.782692307692304|
# |stddev |36.677727272365246|
# |min    |-0.16             |
# |max    |128.8             |
# +-------+------------------+
#
# 🔹 Estadísticas de 'percentage':
# +-------+------------------+
# |summary|percentage        |
# +-------+------------------+
# |count  |156               |
# |mean   |0.4935897435897436|
# |min    |0.0               |
# |max    |1.0               |
# +-------+------------------+
#
# 🔹 Top 5 valores máximos:
# +-------------------+---------+--------------+------------------+
# |datetime           |geo_name |series_title  |value             |
# +-------------------+---------+--------------+------------------+
# |2025-01-31 23:00:00|Península|distinct      |128.8             |
# |2024-11-30 23:00:00|Península|distinct      |125.43            |
# |2024-10-31 23:00:00|Península|distinct      |119.25999999999999|
# |2024-11-30 23:00:00|Península|Mercado diario|113.97            |
# |2024-12-31 23:00:00|Península|distinct      |112.03999999999999|
# +-------------------+---------+--------------+------------------+

# %%
# ============================================
# 4. RECOMENDACIONES PARA SILVER
# ============================================
print("\n" + "=" * 80)
print("💡 4. RECOMENDACIONES PARA CAPA SILVER")
print("=" * 80)

recommendations = """
Basado en el análisis:

1. PARTICIONADO SUGERIDO:
   - Por fecha (year/month) para queries temporales eficientes
   - Por geo_id para análisis regionales

2. TABLAS SILVER PROPUESTAS:
   
   a) slv_demanda_diaria
      - Agregar brz_demanda_evolucion por día
      - Incluir métricas: demanda_real, demanda_prevista
      - Particionar por año/mes y geo_id
   
   b) slv_generacion_mix
      - Combinar estructura_generacion + estructura_renovables
      - Agregar por tecnología y fecha
      - Calcular % renovable vs no renovable
   
   c) slv_balance_horario
      - Desde balance_balance_electrico
      - Mantener granularidad horaria para análisis detallado
      - Enriquecer con datos de precio
   
   d) slv_emisiones
      - Desde estructura_generacion_emisiones_asociadas
      - Agregar por día/mes
      - KPIs: CO2_total, CO2_por_MWh
   
   e) slv_mercado_precios
      - Desde componentes_precio
      - Análisis de componentes del precio eléctrico

3. TRANSFORMACIONES NECESARIAS:
   - Limpieza: Confirmar que no hay duplicados reales
   - Enriquecimiento: Añadir flags (es_renovable, es_peninsula, etc.)
   - Agregaciones: Crear vistas daily/monthly según caso de uso
   - Tipos de datos: Validar que values sean numeric, dates sean timestamp

4. CALIDAD DE DATOS:
   - ✅ Estructura consistente en todas las tablas
   - ✅ Sin nulos críticos en datetime/value
   - ⚠️ Verificar percentage nulls (esperado en algunas series)
   - ⚠️ Confirmar si maxima_renovable tiene suficiente granularidad

5. OPTIMIZACIONES:
   - Z-ORDER por datetime y geo_id en tablas grandes
   - VACUUM periódico para mantener performance
   - Estadísticas de columna para query optimizer
"""

print(recommendations)

print("\n" + "=" * 80)
print("✅ ANÁLISIS COMPLETADO")
print("=" * 80)
# Out:
# StatementMeta(, 9d1c3a59-d18e-4fdf-8498-c7eee8f1135d, 9, Finished, Available, Finished)
# ================================================================================
# 💡 4. RECOMENDACIONES PARA CAPA SILVER
# ================================================================================
#
# Basado en el análisis:
#
# 1. PARTICIONADO SUGERIDO:
#    - Por fecha (year/month) para queries temporales eficientes
#    - Por geo_id para análisis regionales
#
# 2. TABLAS SILVER PROPUESTAS:
#
#    a) slv_demanda_diaria
#       - Agregar brz_demanda_evolucion por día
#       - Incluir métricas: demanda_real, demanda_prevista
#       - Particionar por año/mes y geo_id
#
#    b) slv_generacion_mix
#       - Combinar estructura_generacion + estructura_renovables
#       - Agregar por tecnología y fecha
#       - Calcular % renovable vs no renovable
#
#    c) slv_balance_horario
#       - Desde balance_balance_electrico
#       - Mantener granularidad horaria para análisis detallado
#       - Enriquecer con datos de precio
#
#    d) slv_emisiones
#       - Desde estructura_generacion_emisiones_asociadas
#       - Agregar por día/mes
#       - KPIs: CO2_total, CO2_por_MWh
#
#    e) slv_mercado_precios
#       - Desde componentes_precio
#       - Análisis de componentes del precio eléctrico
#
# 3. TRANSFORMACIONES NECESARIAS:
#    - Limpieza: Confirmar que no hay duplicados reales
#    - Enriquecimiento: Añadir flags (es_renovable, es_peninsula, etc.)
#    - Agregaciones: Crear vistas daily/monthly según caso de uso
#    - Tipos de datos: Validar que values sean numeric, dates sean timestamp
#
# 4. CALIDAD DE DATOS:
#    - ✅ Estructura consistente en todas las tablas
#    - ✅ Sin nulos críticos en datetime/value
#    - ⚠️ Verificar percentage nulls (esperado en algunas series)
#    - ⚠️ Confirmar si maxima_renovable tiene suficiente granularidad
#
# 5. OPTIMIZACIONES:
#    - Z-ORDER por datetime y geo_id en tablas grandes
#    - VACUUM periódico para mantener performance
#    - Estadísticas de columna para query optimizer
#
#
# ================================================================================
# ✅ ANÁLISIS COMPLETADO
# ================================================================================
