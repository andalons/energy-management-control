# %%
import requests, json, time, logging, unicodedata, re
from datetime import datetime, timedelta
from pyspark.sql import SparkSession
import os
from typing import Dict, List, Tuple, Optional
from concurrent.futures import ThreadPoolExecutor, as_completed
from notebookutils import mssparkutils

# Logging simple en consola
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Spark session
spark = SparkSession.builder.appName("REData_API_Explorer").getOrCreate()
# Out:
# StatementMeta(, edf2e257-8379-4838-a9a2-fc48cbfc1924, 13, Finished, Available, Finished)

# %%
class REDataAPIExplorer:
    def __init__(self, base_lakehouse_path: str):
        self.base_url = "https://apidatos.ree.es"
        self.base_lakehouse_path = base_lakehouse_path
        self.session = requests.Session()
        self.headers = {"Accept": "application/json", "Content-Type": "application/json"}

        self.end_date = datetime.now()
        self.start_date = self.end_date - timedelta(days=365)

        # Reducido según briefing: solo categorías clave
        self.api_config = {
            "balance": ["balance-electrico"],
            "demanda": ["evolucion"],
            "generacion": [
                "estructura-generacion",
                "demanda-maxima-diaria",
                "evolucion-renovable-no-renovable",
                "estructura-renovables",
                "estructura-generacion-emisiones-asociadas",
                "maxima-renovable"
            ],
            "intercambios": ["francia-frontera", "portugal-frontera", "marruecos-frontera", "andorra-frontera"],
            "mercados": ["componentes-precio", "precios-mercados-tiempo-real"],
        }

        # Geo con IDs
        self.ccaa_ids = {
            "Andalucía": 4, "Aragón": 5, "Cantabria": 6, "Castilla-La Mancha": 7,
            "Castilla y León": 8, "Cataluña": 9, "País Vasco": 10, "Principado de Asturias": 11,
            "Comunidad de Ceuta": 8744, "Comunidad de Melilla": 8745,
            "Comunidad de Madrid": 13, "Comunidad de Navarra": 14, "Comunidad Valenciana": 15,
            "Extremadura": 16, "Galicia": 17, "Islas Baleares": 8743, "Islas Canarias": 8742,
            "La Rioja": 20, "Región de Murcia": 21, "Península": 8741,
        }
        self.geo_limits = ["peninsular", "canarias", "baleares", "ceuta", "melilla", "ccaa"]
        self.time_truncs = ["day", "month"]

        # Mapa de equivalencias para geo_limit → ccaa_ids
        self.geo_map = {
            "peninsular": "Península",
            "canarias": "Islas Canarias",
            "baleares": "Islas Baleares",
            "ceuta": "Comunidad de Ceuta",
            "melilla": "Comunidad de Melilla",
        }

        # Logs
        self.logs_success = f"{self.base_lakehouse_path}/logs/success.log"
        self.logs_error = f"{self.base_lakehouse_path}/logs/error.log"


    def _slugify(self, text: str) -> str:
        t = unicodedata.normalize("NFKD", text).encode("ascii", "ignore").decode("ascii")
        return re.sub(r"[^a-z0-9\-]", "", t.lower().replace(" ", "-"))

    def build_api_url(self, lang, category, widget, time_trunc, geo_limit, ccaa_name=None):
        start_str = self.start_date.strftime("%Y-%m-%dT%H:%M")
        end_str = self.end_date.strftime("%Y-%m-%dT%H:%M")
        base = f"{self.base_url}/{lang}/datos/{category}/{widget}"

        params = {
            "start_date": start_str,
            "end_date": end_str,
            "time_trunc": time_trunc,
            "geo_trunc": "electric_system",
            "geo_limit": geo_limit
        }

        if geo_limit == "ccaa" and ccaa_name:
            params["geo_ids"] = str(self.ccaa_ids[ccaa_name])
        else:
            mapped_name = self.geo_map[geo_limit]  # usar siempre el mapeo
            params["geo_ids"] = str(self.ccaa_ids[mapped_name])

        query = "&".join([f"{k}={v}" for k, v in params.items()])
        return f"{base}?{query}"


    def make_api_request(self, url: str):
        try:
            r = self.session.get(url, headers=self.headers, timeout=20)
            if r.status_code == 200:
                return True, r.json()
            return False, {}
        except Exception:
            return False, {}

    def save_to_bronze(self, data, category, widget, region, timestamp):
        fname = f"brz-{region}-{category}-{widget}-{timestamp}.json"
        path = f"{self.base_lakehouse_path}/data/{category}/{widget}/{fname}"
        mssparkutils.fs.put(path, json.dumps(data, indent=2, ensure_ascii=False), overwrite=True)
        logger.info(f"✅ Guardado Bronze: {path}")

    def log(self, path, msg: str):
        try:
            mssparkutils.fs.put(path, msg + "\n", overwrite=False)
        except:
            old = ""
            try:
                old = mssparkutils.fs.head(path, 1000000)
            except:
                pass
            mssparkutils.fs.put(path, old + msg + "\n", overwrite=True)

    def explore_single(self, lang, category, widget, time_trunc, geo_limit, ccaa_name=None):
        ts = datetime.utcnow().isoformat(timespec="microseconds") + "Z"
        url = self.build_api_url(lang, category, widget, time_trunc, geo_limit, ccaa_name)
        success, data = self.make_api_request(url)
        has_data = success and bool(data.get("included"))

        region = self._slugify(ccaa_name) if geo_limit == "ccaa" and ccaa_name else geo_limit

        if has_data:
            self.save_to_bronze(data, category, widget, region, ts)
            self.log(self.logs_success, f"{ts} OK {url}")
        else:
            self.log(self.logs_error, f"{ts} FAIL {url}")
        return {"url": url, "success": success, "has_data": has_data}

    def explore_all(self, max_combinations=20):
        combos = []
        for lang in ["es"]:
            for cat, widgets in self.api_config.items():
                for w in widgets:
                    for t in self.time_truncs:
                        for g in self.geo_limits:
                            if g == "ccaa":
                                for ccaa_name in self.ccaa_ids.keys():
                                    if ccaa_name != "Península":
                                        combos.append((lang, cat, w, t, g, ccaa_name))
                            else:
                                combos.append((lang, cat, w, t, g, None))
        combos = combos[:max_combinations]
        logger.info(f"Ejecutando {len(combos)} combinaciones...")
        results = []
        for c in combos:
            results.append(self.explore_single(*c))
            time.sleep(0.2)
        return results

    def analyze_results(self, results):
        total = len(results)
        ok = sum(r["success"] for r in results)
        with_data = sum(r["has_data"] for r in results)
        return {"total": total, "ok": ok, "with_data": with_data, "failures": total - ok}
# Out:
# StatementMeta(, edf2e257-8379-4838-a9a2-fc48cbfc1924, 14, Finished, Available, Finished)

# %%
LAKEHOUSE_PATH = "Files/bronze/redata"
explorer = REDataAPIExplorer(LAKEHOUSE_PATH)

print("✅ Explorador inicializado")
print("Categorías:", list(explorer.api_config.keys()))
# Out:
# StatementMeta(, edf2e257-8379-4838-a9a2-fc48cbfc1924, 15, Finished, Available, Finished)
# ✅ Explorador inicializado
# Categorías: ['balance', 'demanda', 'generacion', 'intercambios', 'mercados']

# %%
# Prueba de construcción de URLs con distintos casos
print("🔎 URL Península:")
print(explorer.build_api_url("es", "demanda", "evolucion", "day", "peninsular"))

print("\n🔎 URL Canarias:")
print(explorer.build_api_url("es", "demanda", "evolucion", "day", "canarias"))

print("\n🔎 URL Cataluña (CCAA):")
print(explorer.build_api_url("es", "demanda", "evolucion", "day", "ccaa", "Cataluña"))
# Out:
# StatementMeta(, edf2e257-8379-4838-a9a2-fc48cbfc1924, 16, Finished, Available, Finished)
# 🔎 URL Península:
# https://apidatos.ree.es/es/datos/demanda/evolucion?start_date=2024-09-23T12:32&end_date=2025-09-23T12:32&time_trunc=day&geo_trunc=electric_system&geo_limit=peninsular&geo_ids=8741
#
# 🔎 URL Canarias:
# https://apidatos.ree.es/es/datos/demanda/evolucion?start_date=2024-09-23T12:32&end_date=2025-09-23T12:32&time_trunc=day&geo_trunc=electric_system&geo_limit=canarias&geo_ids=8742
#
# 🔎 URL Cataluña (CCAA):
# https://apidatos.ree.es/es/datos/demanda/evolucion?start_date=2024-09-23T12:32&end_date=2025-09-23T12:32&time_trunc=day&geo_trunc=electric_system&geo_limit=ccaa&geo_ids=9

# %%
results = explorer.explore_all(max_combinations=None)  
print("✅ Exploración completada")
# Out:
# StatementMeta(, 51a27dc5-d13f-4603-8118-a45e277d1f0a, 12, Finished, Available, Finished)
# INFO:__main__:Ejecutando 336 combinaciones...
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-peninsular-balance-balance-electrico-2025-09-23T11:01:05.474498Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-canarias-balance-balance-electrico-2025-09-23T11:01:13.198880Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-baleares-balance-balance-electrico-2025-09-23T11:01:19.585651Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-ceuta-balance-balance-electrico-2025-09-23T11:01:26.718049Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-melilla-balance-balance-electrico-2025-09-23T11:01:31.982736Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-andalucia-balance-balance-electrico-2025-09-23T11:01:38.271042Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-aragon-balance-balance-electrico-2025-09-23T11:01:43.968275Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-cantabria-balance-balance-electrico-2025-09-23T11:01:49.409035Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-castilla-la-mancha-balance-balance-electrico-2025-09-23T11:01:54.367151Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-castilla-y-leon-balance-balance-electrico-2025-09-23T11:01:58.747664Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-cataluna-balance-balance-electrico-2025-09-23T11:02:04.254403Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-pais-vasco-balance-balance-electrico-2025-09-23T11:02:08.584689Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-principado-de-asturias-balance-balance-electrico-2025-09-23T11:02:13.381046Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-comunidad-de-ceuta-balance-balance-electrico-2025-09-23T11:02:17.673113Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-comunidad-de-melilla-balance-balance-electrico-2025-09-23T11:02:19.161121Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-comunidad-de-madrid-balance-balance-electrico-2025-09-23T11:02:21.155389Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-comunidad-de-navarra-balance-balance-electrico-2025-09-23T11:02:25.997223Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-comunidad-valenciana-balance-balance-electrico-2025-09-23T11:02:29.942450Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-extremadura-balance-balance-electrico-2025-09-23T11:02:34.153001Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-galicia-balance-balance-electrico-2025-09-23T11:02:38.148226Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-islas-baleares-balance-balance-electrico-2025-09-23T11:02:43.083812Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-islas-canarias-balance-balance-electrico-2025-09-23T11:02:45.796508Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-la-rioja-balance-balance-electrico-2025-09-23T11:02:47.754102Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/brz-region-de-murcia-balance-balance-electrico-2025-09-23T11:02:52.063563Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/brz-peninsular-demanda-evolucion-2025-09-23T11:02:56.489383Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/brz-canarias-demanda-evolucion-2025-09-23T11:03:04.131921Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/brz-baleares-demanda-evolucion-2025-09-23T11:03:09.101869Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/brz-ceuta-demanda-evolucion-2025-09-23T11:03:14.817757Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/brz-melilla-demanda-evolucion-2025-09-23T11:03:18.850177Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/brz-peninsular-generacion-estructura-generacion-2025-09-23T11:03:41.682085Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/brz-canarias-generacion-estructura-generacion-2025-09-23T11:03:43.620371Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/brz-baleares-generacion-estructura-generacion-2025-09-23T11:03:45.007327Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/brz-ceuta-generacion-estructura-generacion-2025-09-23T11:03:49.631988Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/brz-melilla-generacion-estructura-generacion-2025-09-23T11:03:50.545452Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/brz-peninsular-generacion-evolucion-renovable-no-renovable-2025-09-23T11:04:28.527818Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/brz-canarias-generacion-evolucion-renovable-no-renovable-2025-09-23T11:04:32.003870Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/brz-baleares-generacion-evolucion-renovable-no-renovable-2025-09-23T11:04:34.930135Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/brz-ceuta-generacion-evolucion-renovable-no-renovable-2025-09-23T11:04:37.846626Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/brz-melilla-generacion-evolucion-renovable-no-renovable-2025-09-23T11:04:40.875949Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/brz-peninsular-generacion-estructura-renovables-2025-09-23T11:05:00.796332Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/brz-canarias-generacion-estructura-renovables-2025-09-23T11:05:02.613460Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/brz-baleares-generacion-estructura-renovables-2025-09-23T11:05:03.740482Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/brz-ceuta-generacion-estructura-renovables-2025-09-23T11:05:06.819866Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/brz-melilla-generacion-estructura-renovables-2025-09-23T11:05:07.839935Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/brz-peninsular-generacion-estructura-generacion-emisiones-asociadas-2025-09-23T11:05:26.624715Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/brz-canarias-generacion-estructura-generacion-emisiones-asociadas-2025-09-23T11:05:28.376875Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/brz-baleares-generacion-estructura-generacion-emisiones-asociadas-2025-09-23T11:05:29.714327Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/brz-ceuta-generacion-estructura-generacion-emisiones-asociadas-2025-09-23T11:05:33.620111Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/brz-melilla-generacion-estructura-generacion-emisiones-asociadas-2025-09-23T11:05:34.555815Z.json
# ✅ Exploración completada

# %%
summary = explorer.analyze_results(results)
print("📊 Resumen de la ejecución:")
print(summary)
# Out:
# StatementMeta(, 51a27dc5-d13f-4603-8118-a45e277d1f0a, 13, Finished, Available, Finished)
# 📊 Resumen de la ejecución:
# {'total': 336, 'ok': 49, 'with_data': 49, 'failures': 287}
