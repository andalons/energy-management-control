# %%
import requests, json, time, logging, unicodedata, re
from datetime import datetime, timedelta
from pyspark.sql import SparkSession
import os
from typing import Dict, List, Tuple, Optional
from concurrent.futures import ThreadPoolExecutor, as_completed
from notebookutils import mssparkutils

# Logging simple en consola
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Spark session
spark = SparkSession.builder.appName("REData_API_Explorer").getOrCreate()
# Out:
# StatementMeta(, c47b6a96-a025-468f-b332-170ec8b48017, 7, Finished, Available, Finished)

# %%
class REDataAPIExplorer:
    def __init__(self, base_lakehouse_path: str):
        self.base_url = "https://apidatos.ree.es"
        self.base_lakehouse_path = base_lakehouse_path
        self.session = requests.Session()
        self.headers = {"Accept": "application/json", "Content-Type": "application/json"}

        self.end_date = datetime.now()
        self.start_date = self.end_date - timedelta(days=365)

        # Reducido según briefing: solo categorías clave
        self.api_config = {
            "balance": ["balance-electrico"],
            "demanda": ["evolucion"],
            "generacion": [
                "estructura-generacion",
                "demanda-maxima-diaria",
                "evolucion-renovable-no-renovable",
                "estructura-renovables",
                "estructura-generacion-emisiones-asociadas",
                "maxima-renovable"
            ],
            "intercambios": ["francia-frontera", "portugal-frontera", "marruecos-frontera", "andorra-frontera"],
            "mercados": ["componentes-precio", "precios-mercados-tiempo-real"],
        }

        # Geo con IDs
        self.ccaa_ids = {
            "Andalucía": 4, "Aragón": 5, "Cantabria": 6, "Castilla-La Mancha": 7,
            "Castilla y León": 8, "Cataluña": 9, "País Vasco": 10, "Principado de Asturias": 11,
            "Comunidad de Ceuta": 8744, "Comunidad de Melilla": 8745,
            "Comunidad de Madrid": 13, "Comunidad de Navarra": 14, "Comunidad Valenciana": 15,
            "Extremadura": 16, "Galicia": 17, "Islas Baleares": 8743, "Islas Canarias": 8742,
            "La Rioja": 20, "Región de Murcia": 21, "Península": 8741,
        }
        self.geo_limits = ["peninsular", "canarias", "baleares", "ceuta", "melilla", "ccaa"]

        # 🔹 Ahora incluye day y month
        self.time_truncs = ["day", "month"]

        # Mapa de equivalencias para geo_limit → ccaa_ids
        self.geo_map = {
            "peninsular": "Península",
            "canarias": "Islas Canarias",
            "baleares": "Islas Baleares",
            "ceuta": "Comunidad de Ceuta",
            "melilla": "Comunidad de Melilla",
        }

        # Logs
        self.logs_success = f"{self.base_lakehouse_path}/logs/success.log"
        self.logs_error = f"{self.base_lakehouse_path}/logs/error.log"


    def _slugify(self, text: str) -> str:
        t = unicodedata.normalize("NFKD", text).encode("ascii", "ignore").decode("ascii")
        return re.sub(r"[^a-z0-9\-]", "", t.lower().replace(" ", "-"))

    def build_api_url(self, lang, category, widget, time_trunc, geo_limit, ccaa_name=None):
        start_str = self.start_date.strftime("%Y-%m-%dT%H:%M")
        end_str = self.end_date.strftime("%Y-%m-%dT%H:%M")
        base = f"{self.base_url}/{lang}/datos/{category}/{widget}"

        params = {
            "start_date": start_str,
            "end_date": end_str,
            "time_trunc": time_trunc,
            "geo_trunc": "electric_system",
            "geo_limit": geo_limit
        }

        if geo_limit == "ccaa" and ccaa_name:
            params["geo_ids"] = str(self.ccaa_ids[ccaa_name])
        else:
            mapped_name = self.geo_map[geo_limit]  # usar siempre el mapeo
            params["geo_ids"] = str(self.ccaa_ids[mapped_name])

        query = "&".join([f"{k}={v}" for k, v in params.items()])
        return f"{base}?{query}"


    def make_api_request(self, url: str):
        try:
            r = self.session.get(url, headers=self.headers, timeout=20)
            if r.status_code == 200:
                return True, r.json()
            return False, {}
        except Exception:
            return False, {}

    def save_to_bronze(self, data, category, widget, region, timestamp, time_trunc):
        fname = f"brz-{region}-{category}-{widget}-{time_trunc}-{timestamp}.json"
        path = f"{self.base_lakehouse_path}/data/{category}/{widget}/{time_trunc}/{fname}"
        mssparkutils.fs.put(path, json.dumps(data, indent=2, ensure_ascii=False), overwrite=True)
        logger.info(f"✅ Guardado Bronze: {path}")

    def log(self, path, msg: str):
        try:
            mssparkutils.fs.put(path, msg + "\n", overwrite=False)
        except:
            old = ""
            try:
                old = mssparkutils.fs.head(path, 1000000)
            except:
                pass
            mssparkutils.fs.put(path, old + msg + "\n", overwrite=True)

    def explore_single(self, lang, category, widget, time_trunc, geo_limit, ccaa_name=None):
        ts = datetime.utcnow().isoformat(timespec="microseconds") + "Z"
        url = self.build_api_url(lang, category, widget, time_trunc, geo_limit, ccaa_name)
        success, data = self.make_api_request(url)
        has_data = success and bool(data.get("included"))

        region = self._slugify(ccaa_name) if geo_limit == "ccaa" and ccaa_name else geo_limit

        if has_data:
            self.save_to_bronze(data, category, widget, region, ts, time_trunc)
            self.log(self.logs_success, f"{ts} OK {url}")
        else:
            self.log(self.logs_error, f"{ts} FAIL {url}")
        return {"url": url, "success": success, "has_data": has_data}

    def explore_all(self, max_combinations=20):
        combos = []
        for lang in ["es"]:
            for cat, widgets in self.api_config.items():
                for w in widgets:
                    for t in self.time_truncs:
                        for g in self.geo_limits:
                            if g == "ccaa":
                                for ccaa_name in self.ccaa_ids.keys():
                                    if ccaa_name != "Península":
                                        combos.append((lang, cat, w, t, g, ccaa_name))
                            else:
                                combos.append((lang, cat, w, t, g, None))
        combos = combos[:max_combinations]
        logger.info(f"Ejecutando {len(combos)} combinaciones...")
        results = []
        for c in combos:
            results.append(self.explore_single(*c))
            time.sleep(0.2)
        return results

    def analyze_results(self, results):
        total = len(results)
        ok = sum(r["success"] for r in results)
        with_data = sum(r["has_data"] for r in results)
        return {"total": total, "ok": ok, "with_data": with_data, "failures": total - ok}
# Out:
# StatementMeta(, c47b6a96-a025-468f-b332-170ec8b48017, 8, Finished, Available, Finished)

# %%
LAKEHOUSE_PATH = "Files/bronze/redata"
explorer = REDataAPIExplorer(LAKEHOUSE_PATH)

print("✅ Explorador inicializado")
print("Categorías:", list(explorer.api_config.keys()))
# Out:
# StatementMeta(, c47b6a96-a025-468f-b332-170ec8b48017, 9, Finished, Available, Finished)
# ✅ Explorador inicializado
# Categorías: ['balance', 'demanda', 'generacion', 'intercambios', 'mercados']

# %%
# Prueba de construcción de URLs con distintos casos
print("🔎 URL Península:")
print(explorer.build_api_url("es", "demanda", "evolucion", "day", "peninsular"))

print("\n🔎 URL Canarias:")
print(explorer.build_api_url("es", "demanda", "evolucion", "day", "canarias"))

print("\n🔎 URL Cataluña (CCAA):")
print(explorer.build_api_url("es", "demanda", "evolucion", "day", "ccaa", "Cataluña"))
# Out:
# StatementMeta(, c47b6a96-a025-468f-b332-170ec8b48017, 10, Finished, Available, Finished)
# 🔎 URL Península:
# https://apidatos.ree.es/es/datos/demanda/evolucion?start_date=2024-09-23T13:19&end_date=2025-09-23T13:19&time_trunc=day&geo_trunc=electric_system&geo_limit=peninsular&geo_ids=8741
#
# 🔎 URL Canarias:
# https://apidatos.ree.es/es/datos/demanda/evolucion?start_date=2024-09-23T13:19&end_date=2025-09-23T13:19&time_trunc=day&geo_trunc=electric_system&geo_limit=canarias&geo_ids=8742
#
# 🔎 URL Cataluña (CCAA):
# https://apidatos.ree.es/es/datos/demanda/evolucion?start_date=2024-09-23T13:19&end_date=2025-09-23T13:19&time_trunc=day&geo_trunc=electric_system&geo_limit=ccaa&geo_ids=9

# %%
results = explorer.explore_all(max_combinations=None)  
print("✅ Exploración completada")
# Out:
# StatementMeta(, c47b6a96-a025-468f-b332-170ec8b48017, 11, Finished, Available, Finished)
# INFO:__main__:Ejecutando 672 combinaciones...
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-peninsular-balance-balance-electrico-day-2025-09-23T13:19:19.101206Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-canarias-balance-balance-electrico-day-2025-09-23T13:19:38.318840Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-baleares-balance-balance-electrico-day-2025-09-23T13:19:51.543863Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-ceuta-balance-balance-electrico-day-2025-09-23T13:19:59.261604Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-melilla-balance-balance-electrico-day-2025-09-23T13:20:13.143786Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-andalucia-balance-balance-electrico-day-2025-09-23T13:20:20.011426Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-aragon-balance-balance-electrico-day-2025-09-23T13:20:24.388215Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-cantabria-balance-balance-electrico-day-2025-09-23T13:20:28.897254Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-castilla-la-mancha-balance-balance-electrico-day-2025-09-23T13:20:33.207609Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-castilla-y-leon-balance-balance-electrico-day-2025-09-23T13:20:37.467527Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-cataluna-balance-balance-electrico-day-2025-09-23T13:20:41.594782Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-pais-vasco-balance-balance-electrico-day-2025-09-23T13:20:46.340748Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-principado-de-asturias-balance-balance-electrico-day-2025-09-23T13:20:51.485731Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-comunidad-de-ceuta-balance-balance-electrico-day-2025-09-23T13:20:55.886846Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-comunidad-de-melilla-balance-balance-electrico-day-2025-09-23T13:20:57.437270Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-comunidad-de-madrid-balance-balance-electrico-day-2025-09-23T13:20:59.206623Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-comunidad-de-navarra-balance-balance-electrico-day-2025-09-23T13:21:04.033143Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-comunidad-valenciana-balance-balance-electrico-day-2025-09-23T13:21:08.483696Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-extremadura-balance-balance-electrico-day-2025-09-23T13:21:12.550432Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-galicia-balance-balance-electrico-day-2025-09-23T13:21:17.036520Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-islas-baleares-balance-balance-electrico-day-2025-09-23T13:21:21.361023Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-islas-canarias-balance-balance-electrico-day-2025-09-23T13:21:24.377513Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-la-rioja-balance-balance-electrico-day-2025-09-23T13:21:26.201378Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/day/brz-region-de-murcia-balance-balance-electrico-day-2025-09-23T13:21:30.063305Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-peninsular-balance-balance-electrico-month-2025-09-23T13:21:34.351769Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-canarias-balance-balance-electrico-month-2025-09-23T13:21:39.128246Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-baleares-balance-balance-electrico-month-2025-09-23T13:21:43.573510Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-ceuta-balance-balance-electrico-month-2025-09-23T13:21:47.938141Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-melilla-balance-balance-electrico-month-2025-09-23T13:21:51.875279Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-andalucia-balance-balance-electrico-month-2025-09-23T13:21:56.115792Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-aragon-balance-balance-electrico-month-2025-09-23T13:21:59.937269Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-cantabria-balance-balance-electrico-month-2025-09-23T13:22:03.868664Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-castilla-la-mancha-balance-balance-electrico-month-2025-09-23T13:22:07.914740Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-castilla-y-leon-balance-balance-electrico-month-2025-09-23T13:22:12.026125Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-cataluna-balance-balance-electrico-month-2025-09-23T13:22:15.971271Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-pais-vasco-balance-balance-electrico-month-2025-09-23T13:22:20.442073Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-principado-de-asturias-balance-balance-electrico-month-2025-09-23T13:22:24.450116Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-comunidad-de-ceuta-balance-balance-electrico-month-2025-09-23T13:22:28.308382Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-comunidad-de-melilla-balance-balance-electrico-month-2025-09-23T13:22:29.605220Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-comunidad-de-madrid-balance-balance-electrico-month-2025-09-23T13:22:30.677430Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-comunidad-de-navarra-balance-balance-electrico-month-2025-09-23T13:22:34.667915Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-comunidad-valenciana-balance-balance-electrico-month-2025-09-23T13:22:38.975579Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-extremadura-balance-balance-electrico-month-2025-09-23T13:22:42.863663Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-galicia-balance-balance-electrico-month-2025-09-23T13:22:46.736263Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-islas-baleares-balance-balance-electrico-month-2025-09-23T13:22:50.608481Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-islas-canarias-balance-balance-electrico-month-2025-09-23T13:22:51.793602Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-la-rioja-balance-balance-electrico-month-2025-09-23T13:22:53.458803Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/balance/balance-electrico/month/brz-region-de-murcia-balance-balance-electrico-month-2025-09-23T13:22:57.492991Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/day/brz-peninsular-demanda-evolucion-day-2025-09-23T13:23:01.438614Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/day/brz-canarias-demanda-evolucion-day-2025-09-23T13:23:07.674796Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/day/brz-baleares-demanda-evolucion-day-2025-09-23T13:23:12.304672Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/day/brz-ceuta-demanda-evolucion-day-2025-09-23T13:23:17.179850Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/day/brz-melilla-demanda-evolucion-day-2025-09-23T13:23:21.334317Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-peninsular-demanda-evolucion-month-2025-09-23T13:23:41.480562Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-canarias-demanda-evolucion-month-2025-09-23T13:23:46.478110Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-baleares-demanda-evolucion-month-2025-09-23T13:23:50.496763Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-ceuta-demanda-evolucion-month-2025-09-23T13:23:54.677457Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-melilla-demanda-evolucion-month-2025-09-23T13:23:58.365453Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-andalucia-demanda-evolucion-month-2025-09-23T13:24:02.196498Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-aragon-demanda-evolucion-month-2025-09-23T13:24:06.185236Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-cantabria-demanda-evolucion-month-2025-09-23T13:24:09.798670Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-castilla-la-mancha-demanda-evolucion-month-2025-09-23T13:24:13.418221Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-castilla-y-leon-demanda-evolucion-month-2025-09-23T13:24:17.190698Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-cataluna-demanda-evolucion-month-2025-09-23T13:24:20.933331Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-pais-vasco-demanda-evolucion-month-2025-09-23T13:24:24.633253Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-principado-de-asturias-demanda-evolucion-month-2025-09-23T13:24:28.330128Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-comunidad-de-ceuta-demanda-evolucion-month-2025-09-23T13:24:31.985079Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-comunidad-de-melilla-demanda-evolucion-month-2025-09-23T13:24:32.968231Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-comunidad-de-madrid-demanda-evolucion-month-2025-09-23T13:24:33.937256Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-comunidad-de-navarra-demanda-evolucion-month-2025-09-23T13:24:37.696094Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-comunidad-valenciana-demanda-evolucion-month-2025-09-23T13:24:41.357494Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-extremadura-demanda-evolucion-month-2025-09-23T13:24:45.001323Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-galicia-demanda-evolucion-month-2025-09-23T13:24:48.736893Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-islas-baleares-demanda-evolucion-month-2025-09-23T13:24:52.524883Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-islas-canarias-demanda-evolucion-month-2025-09-23T13:24:53.522534Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-la-rioja-demanda-evolucion-month-2025-09-23T13:24:54.517352Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/demanda/evolucion/month/brz-region-de-murcia-demanda-evolucion-month-2025-09-23T13:24:58.314520Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/day/brz-peninsular-generacion-estructura-generacion-day-2025-09-23T13:25:02.006783Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/day/brz-canarias-generacion-estructura-generacion-day-2025-09-23T13:25:09.293691Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/day/brz-baleares-generacion-estructura-generacion-day-2025-09-23T13:25:15.011452Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/day/brz-ceuta-generacion-estructura-generacion-day-2025-09-23T13:25:23.229436Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/day/brz-melilla-generacion-estructura-generacion-day-2025-09-23T13:25:27.464377Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-peninsular-generacion-estructura-generacion-month-2025-09-23T13:25:48.175747Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-canarias-generacion-estructura-generacion-month-2025-09-23T13:25:49.318022Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-baleares-generacion-estructura-generacion-month-2025-09-23T13:25:50.188107Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-ceuta-generacion-estructura-generacion-month-2025-09-23T13:25:50.997597Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-melilla-generacion-estructura-generacion-month-2025-09-23T13:25:53.324928Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-andalucia-generacion-estructura-generacion-month-2025-09-23T13:25:54.179706Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-aragon-generacion-estructura-generacion-month-2025-09-23T13:25:55.147384Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-cantabria-generacion-estructura-generacion-month-2025-09-23T13:25:56.129893Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-castilla-la-mancha-generacion-estructura-generacion-month-2025-09-23T13:25:57.125903Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-castilla-y-leon-generacion-estructura-generacion-month-2025-09-23T13:25:58.163173Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-cataluna-generacion-estructura-generacion-month-2025-09-23T13:25:59.123784Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-pais-vasco-generacion-estructura-generacion-month-2025-09-23T13:26:00.072874Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-principado-de-asturias-generacion-estructura-generacion-month-2025-09-23T13:26:00.966954Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-comunidad-de-ceuta-generacion-estructura-generacion-month-2025-09-23T13:26:01.937813Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-comunidad-de-melilla-generacion-estructura-generacion-month-2025-09-23T13:26:02.936347Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-comunidad-de-madrid-generacion-estructura-generacion-month-2025-09-23T13:26:03.891292Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-comunidad-de-navarra-generacion-estructura-generacion-month-2025-09-23T13:26:04.852365Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-comunidad-valenciana-generacion-estructura-generacion-month-2025-09-23T13:26:05.732856Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-extremadura-generacion-estructura-generacion-month-2025-09-23T13:26:06.643197Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-galicia-generacion-estructura-generacion-month-2025-09-23T13:26:07.629301Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-islas-baleares-generacion-estructura-generacion-month-2025-09-23T13:26:10.035118Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-islas-canarias-generacion-estructura-generacion-month-2025-09-23T13:26:11.020468Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-la-rioja-generacion-estructura-generacion-month-2025-09-23T13:26:11.972430Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion/month/brz-region-de-murcia-generacion-estructura-generacion-month-2025-09-23T13:26:12.963080Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/day/brz-peninsular-generacion-evolucion-renovable-no-renovable-day-2025-09-23T13:26:55.190940Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/day/brz-canarias-generacion-evolucion-renovable-no-renovable-day-2025-09-23T13:26:58.804033Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/day/brz-baleares-generacion-evolucion-renovable-no-renovable-day-2025-09-23T13:27:02.267411Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/day/brz-ceuta-generacion-evolucion-renovable-no-renovable-day-2025-09-23T13:27:05.476271Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/day/brz-melilla-generacion-evolucion-renovable-no-renovable-day-2025-09-23T13:27:08.003744Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-peninsular-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:27:26.591810Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-canarias-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:27:32.701204Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-baleares-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:27:38.055835Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-ceuta-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:27:43.265425Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-melilla-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:27:48.094778Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-andalucia-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:27:52.758601Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-aragon-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:27:57.178446Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-cantabria-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:01.617090Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-castilla-la-mancha-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:06.215088Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-castilla-y-leon-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:10.681026Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-cataluna-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:15.510463Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-pais-vasco-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:19.931771Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-principado-de-asturias-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:25.537604Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-comunidad-de-ceuta-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:29.969892Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-comunidad-de-melilla-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:30.988455Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-comunidad-de-madrid-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:31.969764Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-comunidad-de-navarra-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:36.711846Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-comunidad-valenciana-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:41.442857Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-extremadura-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:45.938245Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-galicia-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:50.410938Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-islas-baleares-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:55.197370Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-islas-canarias-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:56.187461Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-la-rioja-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:28:57.173042Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/evolucion-renovable-no-renovable/month/brz-region-de-murcia-generacion-evolucion-renovable-no-renovable-month-2025-09-23T13:29:02.335403Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/day/brz-peninsular-generacion-estructura-renovables-day-2025-09-23T13:29:06.922440Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/day/brz-canarias-generacion-estructura-renovables-day-2025-09-23T13:29:08.247158Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/day/brz-baleares-generacion-estructura-renovables-day-2025-09-23T13:29:09.317337Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/day/brz-ceuta-generacion-estructura-renovables-day-2025-09-23T13:29:10.362027Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/day/brz-melilla-generacion-estructura-renovables-day-2025-09-23T13:29:11.198722Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-peninsular-generacion-estructura-renovables-month-2025-09-23T13:29:28.563288Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-canarias-generacion-estructura-renovables-month-2025-09-23T13:29:30.299096Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-baleares-generacion-estructura-renovables-month-2025-09-23T13:29:31.894270Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-ceuta-generacion-estructura-renovables-month-2025-09-23T13:29:33.216018Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-melilla-generacion-estructura-renovables-month-2025-09-23T13:29:34.537744Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-andalucia-generacion-estructura-renovables-month-2025-09-23T13:29:35.879267Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-aragon-generacion-estructura-renovables-month-2025-09-23T13:29:37.212009Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-cantabria-generacion-estructura-renovables-month-2025-09-23T13:29:38.452861Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-castilla-la-mancha-generacion-estructura-renovables-month-2025-09-23T13:29:39.812291Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-castilla-y-leon-generacion-estructura-renovables-month-2025-09-23T13:29:41.187654Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-cataluna-generacion-estructura-renovables-month-2025-09-23T13:29:42.580327Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-pais-vasco-generacion-estructura-renovables-month-2025-09-23T13:29:43.999174Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-principado-de-asturias-generacion-estructura-renovables-month-2025-09-23T13:29:45.284329Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-comunidad-de-ceuta-generacion-estructura-renovables-month-2025-09-23T13:29:46.651204Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-comunidad-de-melilla-generacion-estructura-renovables-month-2025-09-23T13:29:47.744763Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-comunidad-de-madrid-generacion-estructura-renovables-month-2025-09-23T13:29:48.830236Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-comunidad-de-navarra-generacion-estructura-renovables-month-2025-09-23T13:29:50.200942Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-comunidad-valenciana-generacion-estructura-renovables-month-2025-09-23T13:29:51.590126Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-extremadura-generacion-estructura-renovables-month-2025-09-23T13:29:53.044953Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-galicia-generacion-estructura-renovables-month-2025-09-23T13:29:54.542409Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-islas-baleares-generacion-estructura-renovables-month-2025-09-23T13:29:56.060403Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-islas-canarias-generacion-estructura-renovables-month-2025-09-23T13:29:57.210663Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-la-rioja-generacion-estructura-renovables-month-2025-09-23T13:29:58.364445Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-renovables/month/brz-region-de-murcia-generacion-estructura-renovables-month-2025-09-23T13:29:59.811434Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/day/brz-peninsular-generacion-estructura-generacion-emisiones-asociadas-day-2025-09-23T13:30:01.317104Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/day/brz-canarias-generacion-estructura-generacion-emisiones-asociadas-day-2025-09-23T13:30:03.159336Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/day/brz-baleares-generacion-estructura-generacion-emisiones-asociadas-day-2025-09-23T13:30:04.766691Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/day/brz-ceuta-generacion-estructura-generacion-emisiones-asociadas-day-2025-09-23T13:30:09.340371Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/day/brz-melilla-generacion-estructura-generacion-emisiones-asociadas-day-2025-09-23T13:30:10.430836Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-peninsular-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:33.147581Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-canarias-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:34.886296Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-baleares-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:36.311757Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-ceuta-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:37.802004Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-melilla-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:39.252093Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-andalucia-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:40.788139Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-aragon-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:42.192462Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-cantabria-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:43.622457Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-castilla-la-mancha-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:45.075895Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-castilla-y-leon-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:46.444823Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-cataluna-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:47.737158Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-pais-vasco-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:49.146366Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-principado-de-asturias-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:50.494493Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-comunidad-de-ceuta-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:51.827245Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-comunidad-de-melilla-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:52.874872Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-comunidad-de-madrid-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:53.921142Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-comunidad-de-navarra-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:55.417328Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-comunidad-valenciana-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:56.792530Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-extremadura-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:58.092132Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-galicia-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:30:59.357022Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-islas-baleares-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:31:00.664968Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-islas-canarias-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:31:01.808975Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-la-rioja-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:31:02.934218Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/estructura-generacion-emisiones-asociadas/month/brz-region-de-murcia-generacion-estructura-generacion-emisiones-asociadas-month-2025-09-23T13:31:04.257804Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/maxima-renovable/month/brz-peninsular-generacion-maxima-renovable-month-2025-09-23T13:31:27.299446Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/maxima-renovable/month/brz-canarias-generacion-maxima-renovable-month-2025-09-23T13:31:29.729105Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/maxima-renovable/month/brz-baleares-generacion-maxima-renovable-month-2025-09-23T13:31:31.572518Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/maxima-renovable/month/brz-ceuta-generacion-maxima-renovable-month-2025-09-23T13:31:33.290522Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/generacion/maxima-renovable/month/brz-melilla-generacion-maxima-renovable-month-2025-09-23T13:31:34.996139Z.json
# INFO:__main__:✅ Guardado Bronze: Files/bronze/redata/data/mercados/componentes-precio/month/brz-peninsular-mercados-componentes-precio-month-2025-09-23T13:35:02.606181Z.json
# ✅ Exploración completada

# %%
summary = explorer.analyze_results(results)
print("📊 Resumen de la ejecución:")
print(summary)
# Out:
# StatementMeta(, c47b6a96-a025-468f-b332-170ec8b48017, 12, Finished, Available, Finished)
# 📊 Resumen de la ejecución:
# {'total': 672, 'ok': 199, 'with_data': 199, 'failures': 473}
