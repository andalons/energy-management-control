# %%
import os, re, unicodedata
from datetime import datetime
from pyspark.sql import SparkSession, functions as F
from notebookutils import mssparkutils
# Out:
# StatementMeta(, 150330c9-3170-466c-adab-217180435294, 3, Finished, Available, Finished)

# %%
# ---------- Spark ----------
spark = SparkSession.builder.getOrCreate()
# Out:
# StatementMeta(, 150330c9-3170-466c-adab-217180435294, 4, Finished, Available, Finished)

# %%
# Seleccionar el Lakehouse destino (silver)
spark.sql("USE lh_silver")
# Out:
# StatementMeta(, 150330c9-3170-466c-adab-217180435294, 5, Finished, Available, Finished)
# DataFrame[]

# %%
# 📂 Carpetas bronze (donde ya están los JSON)
bronze_base_logical = "Files/bronze/ESIOS/data/balance/balance-electrico"
bronze_base_physical = "/lakehouse/default/Files/bronze/ESIOS/data/balance/balance-electrico"
# Out:
# StatementMeta(, 150330c9-3170-466c-adab-217180435294, 6, Finished, Available, Finished)

# %%
# 📂 Salida (Tables/)
tables_prefix = "Tables"
# Out:
# StatementMeta(, 150330c9-3170-466c-adab-217180435294, 7, Finished, Available, Finished)

# %%
# --------------------------
# Función utilitaria mejorada
# --------------------------
def slugify(name: str) -> str:
    # Normalizar y quitar tildes
    name = unicodedata.normalize("NFKD", name)
    name = name.encode("ascii", "ignore").decode("utf-8")  # quita acentos
    # Sustituir caracteres no válidos por "_"
    return re.sub(r'[^a-z0-9_]', '_', name.lower())
# Out:
# StatementMeta(, 150330c9-3170-466c-adab-217180435294, 8, Finished, Available, Finished)

# %%
## --------------------------
# Procesamiento
# --------------------------
total_rows = 0

# Listar granularidades (day, month)
granularities = [g.name for g in mssparkutils.fs.ls(bronze_base_logical) if g.isDir]

for trunc in granularities:
    years_dirs = mssparkutils.fs.ls(f"{bronze_base_logical}/{trunc}")
    for year_dir in years_dirs:
        year = year_dir.name
        json_files = mssparkutils.fs.ls(year_dir.path)
        for f in json_files:
            if not f.path.endswith(".json"):
                continue

            print(f"\n🔎 Procesando {f.path}")

            # Leer JSON
            df_raw = spark.read.option("multiline", True).json(f.path)

            # Extraer indicador, values
            indicator_id = df_raw.select("indicator.id").first()[0]
            indicator_type = df_raw.select("indicator.short_name").first()[0] \
                              if "short_name" in df_raw.select("indicator.*").columns else indicator_id

            values = df_raw.selectExpr("explode(indicator.values) as val") \
                           .select("val.*")

            if values.rdd.isEmpty():
                print("⚠️ JSON vacío (sin values), skipping")
                continue

            # Enriquecer con metadatos
            df = (values
                  .withColumn("indicator_id", F.lit(indicator_id))
                  .withColumn("indicator_type", F.lit(indicator_type))
                  .withColumn("year", F.lit(int(year)))
                  .withColumn("time_trunc", F.lit(trunc))
                  .withColumn("ingestion_date", F.current_timestamp())
                 )

            # Nombre tabla → según tipo de indicador y trunc
            indicator_slug = slugify(indicator_type)
            table_name = f"slv_esios_balance_{indicator_slug}_{trunc}"

            # Guardar en Delta gestionado (en Lakehouse lh_silver)
            df.write.format("delta").mode("append").saveAsTable(table_name)

            count = df.count()
            total_rows += count
            print(f"✅ Guardado en tabla {table_name} ({count} registros)")

print(f"\nProceso terminado - {datetime.utcnow().isoformat()}Z")
print(f"Total registros procesados: {total_rows}")
# Out:
# StatementMeta(, 150330c9-3170-466c-adab-217180435294, 9, Finished, Available, Finished)
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-carbon-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_carbon_month (31 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-ciclo-combinado-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_ciclo_combinado_month (155 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-cogeneracion-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_cogeneracion_month (192 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-consumo-bombeo-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_consumo_de_bombeo_month (120 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-eolica-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_eolica_month (190 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-hidraulica-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_hidraulica_month (192 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-otras-renovables-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_otras_renovables_month (204 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-residuos-no-renovables-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_residuos_no_renovables_month (131 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-saldo-intercambios-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_saldo_intercambios_month (192 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-solar-fotovoltaica-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_solar_fotovoltaica_month (220 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-solar-termica-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_solar_termico_month (72 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2023/brz-balance-turbinacion-bombeo-month-2023.json
# ✅ Guardado en tabla slv_esios_balance_turbinacion_bombeo_month (120 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-carbon-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_carbon_month (20 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-ciclo-combinado-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_ciclo_combinado_month (156 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-cogeneracion-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_cogeneracion_month (192 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-consumo-bombeo-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_consumo_de_bombeo_month (120 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-eolica-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_eolica_month (180 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-hidraulica-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_hidraulica_month (192 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-otras-renovables-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_otras_renovables_month (204 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-residuos-no-renovables-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_residuos_no_renovables_month (131 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-saldo-intercambios-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_saldo_intercambios_month (192 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-solar-fotovoltaica-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_solar_fotovoltaica_month (224 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-solar-termica-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_solar_termico_month (72 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2024/brz-balance-turbinacion-bombeo-month-2024.json
# ✅ Guardado en tabla slv_esios_balance_turbinacion_bombeo_month (120 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-carbon-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_carbon_month (9 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-ciclo-combinado-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_ciclo_combinado_month (52 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-cogeneracion-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_cogeneracion_month (64 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-consumo-bombeo-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_consumo_de_bombeo_month (40 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-eolica-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_eolica_month (60 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-hidraulica-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_hidraulica_month (62 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-otras-renovables-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_otras_renovables_month (68 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-residuos-no-renovables-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_residuos_no_renovables_month (44 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-saldo-intercambios-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_saldo_intercambios_month (64 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-solar-fotovoltaica-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_solar_fotovoltaica_month (71 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-solar-termica-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_solar_termico_month (24 registros)
#
# 🔎 Procesando abfss://ecf938c4-c449-48de-a07c-1d968a72b3d1@onelake.dfs.fabric.microsoft.com/0fd09a67-0164-4fb6-838e-02a27c823afc/Files/bronze/ESIOS/data/balance/balance-electrico/month/2025/brz-balance-turbinacion-bombeo-month-2025.json
# ✅ Guardado en tabla slv_esios_balance_turbinacion_bombeo_month (40 registros)
#
# Proceso terminado - 2025-10-01T12:25:55.286850Z
# Total registros procesados: 4220
